# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  f = zipfile.ZipFile(filename)
  for name in f.namelist():
    return tf.compat.as_str(f.read(name)).split()
  f.close()
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# ('Most common words (+UNK)', [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)])
# ('Sample data', [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156])

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# ('data:', ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first'])
#
# with num_skips = 2 and skip_window = 1:
# ('    batch:', ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term'])
# ('    labels:', ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'a', 'of'])
#
# with num_skips = 4 and skip_window = 2:
# ('    batch:', ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a'])
# ('    labels:', ['a', 'term', 'anarchism', 'originated', 'originated', 'as', 'term', 'of'])

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.887227
# Nearest to are: lom, notorious, florence, galatia, battery, witted, cuzco, knows,
# Nearest to their: vortigern, borrowings, austrian, linguistic, edged, peloponnesus, layton, disinfectant,
# Nearest to state: consecutive, mile, leif, howland, hittite, redness, conductivity, transgender,
# Nearest to over: kew, transform, intervention, integer, goods, judoka, synonym, westward,
# Nearest to five: homologous, presto, kristen, truman, illuminism, mips, boric, cob,
# Nearest to for: narrower, organist, himself, inconclusive, blond, emits, forecasts, lascaris,
# Nearest to may: discovered, morel, impiety, skyscrapers, power, earl, colombo, scriptorium,
# Nearest to have: moulded, cacm, footnotes, aileen, cyclopentadienyl, propellers, psychologist, minced,
# Nearest to often: resuscitation, corporatism, entry, neolithic, doorstep, bac, kreutzmann, triumvirate,
# Nearest to four: absolutist, seed, oppose, privates, merv, speculative, classifications, sliding,
# Nearest to from: batmobile, rohde, posture, timid, staphylococcus, implementations, blockbuster, dmz,
# Nearest to which: labyrinth, scattering, huron, notches, pardo, sds, crown, solid,
# Nearest to and: zil, sparta, rossi, nicky, eating, soo, omitted, navigate,
# Nearest to used: proudest, stags, cones, haemophilia, parte, buell, extradited, mcbeal,
# Nearest to after: lendl, pederasty, admire, bistable, ethelred, longue, normative, marcomanni,
# Nearest to at: blackmail, slapping, document, falsification, leaflets, exothermic, impaled, bakassi,
# Average loss at step 2000: 4.360996
# Average loss at step 4000: 3.865378
# Average loss at step 6000: 3.786592
# Average loss at step 8000: 3.686892
# Average loss at step 10000: 3.613068
# Nearest to are: were, is, have, commensurate, was, hospitality, troy, although,
# Nearest to their: his, its, her, nobi, yeltsin, fiddlers, linguistic, cern,
# Nearest to state: consecutive, hittite, sedimentation, cunt, ejaculate, receivers, mile, dubna,
# Nearest to over: integer, polytechnical, sterreich, gypsy, kew, cotangent, against, noradrenaline,
# Nearest to five: six, three, eight, four, seven, nine, zero, two,
# Nearest to for: in, intensities, of, breathtaking, with, at, spells, ethics,
# Nearest to may: will, would, can, skyscrapers, colombo, discovered, genosha, ducas,
# Nearest to have: had, be, has, disembodied, are, were, mitt, haken,
# Nearest to often: sometimes, spirited, never, also, not, integrable, itself, unorthodox,
# Nearest to four: six, three, five, seven, eight, two, nine, zero,
# Nearest to from: in, dmz, shoddy, pen, into, after, at, senegalese,
# Nearest to which: who, this, that, pardo, it, ajiva, also, fair,
# Nearest to and: or, who, on, although, by, rim, s, in,
# Nearest to used: proudest, considered, glenn, fcc, extradited, known, igf, haemophilia,
# Nearest to after: before, from, exoskeleton, mammals, during, hava, coloane, since,
# Nearest to at: in, on, during, following, nicodemus, through, for, from,
# Average loss at step 12000: 3.607041
# Average loss at step 14000: 3.575320
# Average loss at step 16000: 3.414965
# Average loss at step 18000: 3.455570
# Average loss at step 20000: 3.541620
# Nearest to are: were, is, have, although, being, other, was, be,
# Nearest to their: its, his, her, the, some, this, nobi, yeltsin,
# Nearest to state: consecutive, inner, receivers, dubna, mile, harassing, winningest, hittite,
# Nearest to over: gypsy, noradrenaline, melchizedek, integer, manmade, against, sumo, polytechnical,
# Nearest to five: seven, six, three, four, eight, zero, two, nine,
# Nearest to for: of, in, by, with, ethics, spells, bungalow, emits,
# Nearest to may: can, would, will, could, cannot, might, must, emulsions,
# Nearest to have: had, has, be, were, are, disembodied, mitt, sasha,
# Nearest to often: sometimes, also, never, spirited, which, now, itself, depose,
# Nearest to four: three, six, eight, seven, five, two, nine, zero,
# Nearest to from: into, in, concur, after, between, dmz, and, at,
# Nearest to which: who, that, this, but, also, it, cayley, still,
# Nearest to and: or, but, which, from, in, whose, exoskeleton, at,
# Nearest to used: considered, known, extradited, glenn, fcc, found, proudest, seen,
# Nearest to after: before, when, mammals, from, during, at, kou, by,
# Nearest to at: in, during, germanic, on, following, from, after, and,
# Average loss at step 22000: 3.503017
# Average loss at step 24000: 3.489133
# Average loss at step 26000: 3.483840
# Average loss at step 28000: 3.478407
# Average loss at step 30000: 3.500412
# Nearest to are: were, have, is, these, other, although, but, deteriorate,
# Nearest to their: its, his, the, her, some, these, them, many,
# Nearest to state: philosophy, dubna, receivers, consecutive, harassing, inner, sedimentation, start,
# Nearest to over: gypsy, binary, goods, manmade, noradrenaline, kew, chs, cotangent,
# Nearest to five: four, seven, eight, six, three, zero, nine, two,
# Nearest to for: when, emits, alright, breathtaking, with, of, under, elegans,
# Nearest to may: would, can, will, could, must, cannot, might, should,
# Nearest to have: had, has, were, are, be, having, disembodied, mitt,
# Nearest to often: sometimes, also, now, typically, still, usually, commonly, spirited,
# Nearest to four: five, three, eight, six, seven, two, nine, zero,
# Nearest to from: into, after, shoddy, under, during, jute, between, dmz,
# Nearest to which: this, that, who, also, what, it, burghers, but,
# Nearest to and: or, but, overseer, who, tumbling, existentialism, decks, in,
# Nearest to used: known, found, considered, seen, available, mentioned, glenn, pole,
# Nearest to after: before, during, when, from, since, at, exoskeleton, ekam,
# Nearest to at: in, during, on, germanic, supervisors, loo, equity, after,
# Average loss at step 32000: 3.500321
# Average loss at step 34000: 3.495546
# Average loss at step 36000: 3.457010
# Average loss at step 38000: 3.305327
# Average loss at step 40000: 3.429804
# Nearest to are: were, have, is, include, these, custis, although, including,
# Nearest to their: its, his, her, some, the, these, them, any,
# Nearest to state: dubna, start, inner, comply, macros, government, ccf, philosophy,
# Nearest to over: gypsy, goods, binary, noradrenaline, misfortune, away, vivekananda, cafes,
# Nearest to five: seven, six, four, eight, three, zero, two, nine,
# Nearest to for: spells, in, grossing, when, of, metro, breathtaking, mumps,
# Nearest to may: can, would, will, could, must, might, should, cannot,
# Nearest to have: had, has, were, are, be, include, already, mitt,
# Nearest to often: sometimes, usually, also, still, commonly, now, typically, generally,
# Nearest to four: six, three, seven, five, two, eight, one, nine,
# Nearest to from: after, into, detectable, between, better, during, shoddy, in,
# Nearest to which: that, this, also, who, it, what, these, often,
# Nearest to and: or, jail, clock, like, but, including, spaceman, teleology,
# Nearest to used: known, found, available, considered, seen, mentioned, applied, designed,
# Nearest to after: before, during, when, from, while, through, raw, since,
# Nearest to at: during, on, equity, vetoes, meccans, in, maus, lufthansa,
# Average loss at step 42000: 3.432622
# Average loss at step 44000: 3.451154
# Average loss at step 46000: 3.451974
# Average loss at step 48000: 3.351676
# Average loss at step 50000: 3.382028
# Nearest to are: were, is, have, these, was, being, be, dagger,
# Nearest to their: its, his, her, the, some, several, these, your,
# Nearest to state: inner, dubna, comply, treatment, start, receivers, distorting, ccf,
# Nearest to over: through, gypsy, off, tribes, kew, about, noradrenaline, away,
# Nearest to five: four, six, seven, eight, three, zero, two, nine,
# Nearest to for: while, breathtaking, emits, throughout, azerbaijani, including, pershing, dysphoria,
# Nearest to may: can, would, could, will, must, should, might, cannot,
# Nearest to have: had, has, were, be, are, having, prefer, who,
# Nearest to often: sometimes, usually, still, commonly, generally, now, frequently, also,
# Nearest to four: six, eight, five, three, seven, nine, two, zero,
# Nearest to from: into, in, after, during, eschatology, detectable, through, dmz,
# Nearest to which: that, this, also, who, often, what, both, usually,
# Nearest to and: or, but, including, iraqi, of, however, catalana, internationals,
# Nearest to used: known, found, available, seen, considered, referred, applied, mentioned,
# Nearest to after: before, when, during, while, from, byers, at, since,
# Nearest to at: during, equity, on, gp, after, meccans, garret, before,
# Average loss at step 52000: 3.442691
# Average loss at step 54000: 3.428178
# Average loss at step 56000: 3.436818
# Average loss at step 58000: 3.397246
# Average loss at step 60000: 3.393019
# Nearest to are: were, is, have, but, these, although, include, exist,
# Nearest to their: its, his, her, the, several, your, some, quanta,
# Nearest to state: receivers, start, inner, philosophy, government, treatment, dubna, distorting,
# Nearest to over: through, about, away, across, kew, gypsy, noradrenaline, tribes,
# Nearest to five: six, four, three, eight, seven, zero, nine, two,
# Nearest to for: of, including, emits, breathtaking, transitional, when, colspan, thousand,
# Nearest to may: can, will, would, could, must, should, might, cannot,
# Nearest to have: has, had, are, were, include, be, having, skyscrapers,
# Nearest to often: sometimes, usually, commonly, still, frequently, generally, now, widely,
# Nearest to four: six, eight, five, three, seven, nine, two, zero,
# Nearest to from: into, in, through, after, including, alas, concur, between,
# Nearest to which: that, this, what, however, it, but, these, who,
# Nearest to and: or, but, including, although, organically, than, catalana, lfc,
# Nearest to used: known, available, found, seen, mentioned, designed, considered, applied,
# Nearest to after: before, during, when, while, from, despite, although, following,
# Nearest to at: during, in, within, equity, vetoes, loo, auguste, maus,
# Average loss at step 62000: 3.241363
# Average loss at step 64000: 3.251600
# Average loss at step 66000: 3.402463
# Average loss at step 68000: 3.397589
# Average loss at step 70000: 3.358773
# Nearest to are: were, have, is, include, although, these, including, be,
# Nearest to their: its, his, her, the, your, these, our, whose,
# Nearest to state: government, receivers, distorting, states, inner, city, dubna, winningest,
# Nearest to over: through, about, jyutping, away, kew, around, off, across,
# Nearest to five: four, six, three, seven, eight, zero, nine, two,
# Nearest to for: transitional, emits, in, breathtaking, of, if, while, terrorist,
# Nearest to may: can, could, would, will, must, should, might, cannot,
# Nearest to have: had, has, are, were, include, prefer, be, having,
# Nearest to often: sometimes, usually, frequently, commonly, still, generally, now, typically,
# Nearest to four: three, six, five, seven, eight, two, zero, nine,
# Nearest to from: into, through, in, during, alas, boomerang, between, within,
# Nearest to which: that, this, what, also, but, still, however, and,
# Nearest to and: or, but, of, which, while, transgender, mature, including,
# Nearest to used: known, seen, available, found, mentioned, applied, referred, considered,
# Nearest to after: before, during, when, while, despite, until, through, though,
# Nearest to at: during, vetoes, lobos, maus, equity, in, gp, on,
# Average loss at step 72000: 3.376176
# Average loss at step 74000: 3.345114
# Average loss at step 76000: 3.322723
# Average loss at step 78000: 3.349887
# Average loss at step 80000: 3.376986
# Nearest to are: were, is, have, include, those, although, bev, these,
# Nearest to their: its, his, her, your, the, these, our, several,
# Nearest to state: city, receivers, government, states, distorting, comply, mysteriously, inner,
# Nearest to over: through, around, about, off, within, across, kew, away,
# Nearest to five: six, four, seven, three, eight, zero, nine, two,
# Nearest to for: emits, transitional, against, while, recitative, compiler, remit, although,
# Nearest to may: can, could, will, would, must, should, might, cannot,
# Nearest to have: had, has, include, are, be, having, were, prefer,
# Nearest to often: sometimes, usually, commonly, frequently, generally, still, typically, now,
# Nearest to four: six, five, three, seven, eight, two, nine, zero,
# Nearest to from: through, into, jute, in, detectable, after, within, posture,
# Nearest to which: that, this, what, usually, also, but, actually, straps,
# Nearest to and: or, including, but, than, vaishnavism, gorgeous, tuscany, discusses,
# Nearest to used: known, seen, referred, found, available, mentioned, applied, designed,
# Nearest to after: before, during, when, while, despite, though, without, until,
# Nearest to at: in, on, during, within, once, gp, after, before,
# Average loss at step 82000: 3.408405
# Average loss at step 84000: 3.409571
# Average loss at step 86000: 3.391715
# Average loss at step 88000: 3.357617
# Average loss at step 90000: 3.361719
# Nearest to are: were, is, include, have, these, although, suggesting, centum,
# Nearest to their: its, his, her, your, our, them, the, my,
# Nearest to state: city, government, receivers, states, inner, treatment, corea, macros,
# Nearest to over: within, off, around, through, about, across, vivekananda, away,
# Nearest to five: seven, four, three, six, eight, nine, zero, two,
# Nearest to for: of, including, after, recitative, despite, without, musica, emits,
# Nearest to may: can, could, would, will, should, must, might, cannot,
# Nearest to have: had, has, include, are, were, having, be, prefer,
# Nearest to often: sometimes, usually, commonly, frequently, generally, also, typically, now,
# Nearest to four: seven, five, six, three, eight, two, nine, zero,
# Nearest to from: through, into, during, shoddy, propounded, after, within, across,
# Nearest to which: that, this, what, but, also, who, usually, burghers,
# Nearest to and: or, but, including, tipperary, combative, while, lfc, weighty,
# Nearest to used: known, seen, applied, found, referred, available, described, called,
# Nearest to after: before, during, when, while, until, despite, without, though,
# Nearest to at: during, once, in, after, near, until, while, on,
# Average loss at step 92000: 3.399948
# Average loss at step 94000: 3.255306
# Average loss at step 96000: 3.356401
# Average loss at step 98000: 3.239645
# Average loss at step 100000: 3.359975
# Nearest to are: were, have, those, these, premierships, be, sparse, include,
# Nearest to their: its, his, her, your, the, our, several, these,
# Nearest to state: city, states, government, receivers, macros, start, potawatomi, hellespont,
# Nearest to over: within, around, off, vivekananda, across, through, racial, misfortune,
# Nearest to five: four, six, seven, eight, three, zero, two, nine,
# Nearest to for: emits, racquets, when, musica, without, after, while, colspan,
# Nearest to may: can, could, should, might, would, must, will, cannot,
# Nearest to have: had, has, include, are, were, be, prefer, provide,
# Nearest to often: sometimes, usually, commonly, frequently, generally, typically, still, now,
# Nearest to four: six, five, seven, eight, three, two, nine, zero,
# Nearest to from: into, through, in, shoddy, within, dmz, during, propounded,
# Nearest to which: that, this, what, these, actually, but, valium, usually,
# Nearest to and: or, but, although, while, including, however, magdalen, to,
# Nearest to used: seen, applied, found, known, referred, available, designed, cited,
# Nearest to after: before, during, when, despite, until, without, while, at,
# Nearest to at: during, on, after, within, with, once, gp, in,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to Word2Vec is called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
batch_size = 128
context_window = 4 # How many words to consider left and right
start_index = 0
    
def generate_cbow_batch(batch_size, context_size):
  batch_size = batch_size * context_window
  global start_index
  assert (context_size + 1) % 2 == 1 # the context for a word should always have even number of elements on each side
  assert batch_size % (context_size) == 0 # should fail if we cannot fit exactly N contexts in one batch
 
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size / context_size, 1), dtype=np.int32)
  # 0,1,2,3 4,5,6,7
  mid_element = context_size / 2
  for i in range(batch_size / context_size):
    buffer = [None] * context_size
    for j in range(context_size + 1):
      idx = (start_index + j) % len(data)
      mid_element_idx = (start_index + mid_element) % len(data)
     
      if idx < mid_element_idx:
        buffer[j] = data[idx]
      elif idx > mid_element_idx:
        buffer[j-1] = data[idx]
      else:
        labels[i,0] = data[mid_element_idx]
    random.shuffle(buffer)
    for j in range(context_size):
      batch[i*context_size + j] = buffer[j]
    start_index = (start_index + 1) % len(data)
   
  return batch, labels
 
b_size=20
c_size=4
batch, labels = generate_cbow_batch(batch_size=b_size, context_size=c_size)
for i in range(b_size / (c_size)):
  print "context for %s:" % reverse_dictionary[labels[i,0]]
  for j in range(c_size):
    print reverse_dictionary[batch[i*(c_size) + j]]
# Out:
# context for as:
# originated
# anarchism
# term
# a
# context for a:
# originated
# term
# as
# of
# context for term:
# as
# of
# a
# abuse
# context for of:
# first
# term
# a
# abuse
# context for abuse:
# term
# first
# of
# used

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
context_window = 4 # How many words to consider left and right
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(xrange(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.
 
graph = tf.Graph()
 
with graph.as_default():
 
  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size * context_window])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
 
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  segments = tf.constant([x / context_window for x in range(batch_size * context_window)])
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
 
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  compressed_embeddings = tf.segment_sum(embed, segments) # merging couple of embeded words into one input
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, compressed_embeddings,
                               train_labels, num_sampled, vocabulary_size))
 
  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
 
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
 
  input = [dictionary["anarchism"], dictionary["originated"], dictionary["a"], dictionary["term"]] * batch_size
 
  logits = tf.matmul(compressed_embeddings, tf.transpose(softmax_weights)) + softmax_biases
  y_ = tf.nn.softmax(logits)

# %%
num_steps = 100001
debug = False
 
with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print "Initialized"
  average_loss = 0
  if debug:
      feed_dict = {train_dataset : input}
      _, yy = session.run([logits, y_], feed_dict=feed_dict)
     
      top_k = 8 # number of nearest neighbors
      for i in xrange(7):
        print [reverse_dictionary[x] for x in (-yy[i, :]).argsort()[1:top_k+1]]
  else:
      for step in xrange(num_steps):
        batch_data, batch_labels = generate_cbow_batch(batch_size, context_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
       
        average_loss += l
        if step % 2000 == 0:
          if step > 0:
            average_loss = average_loss / 2000
          # The average loss is an estimate of the loss over the last 2000 batches.
          print "Average loss at step", step, ":", average_loss
          average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
          sim = similarity.eval()
          for i in xrange(valid_size):
            valid_word = reverse_dictionary[valid_examples[i]]
            top_k = 8 # number of nearest neighbors
            nearest = (-sim[i, :]).argsort()[1:top_k+1]
            log = "Nearest to %s:" % valid_word
            for k in xrange(top_k):
              close_word = reverse_dictionary[nearest[k]]
              log = "%s %s," % (log, close_word)
            print log
      final_embeddings = normalized_embeddings.eval()
     
      # feeds the algorithm a context and gets the most probable autocompletion/autocorrection
      feed_dict = {train_dataset : input}
      _, y = session.run([logits, y_], feed_dict=feed_dict)
 
      top_k = 8 # number of nearest neighbors
      for i in xrange(7):
        print [reverse_dictionary[x] for x in (-y[i, :]).argsort()[1:top_k+1]]
# Out:
# Initialized
# Average loss at step 0 : 8.21737098694
# Nearest to during: com, municipalities, masjid, affectionately, nothing, infirmities, shavuot, felis,
# Nearest to for: extracellular, freshmen, chronicon, marches, kindling, eyeglasses, niece, councilors,
# Nearest to many: demanded, emet, rau, orbiter, banisteriopsis, jagiellon, teeming, identifying,
# Nearest to two: ambulatory, roussimoff, breakdowns, amerindians, tenet, costly, thereabouts, wits,
# Nearest to been: foreknowledge, internationally, magnitudes, outlets, bronfman, etiquette, moyen, icy,
# Nearest to all: haganah, eligibility, bil, opening, mailed, firepower, palaces, ob,
# Nearest to he: mdf, affections, return, bought, distressed, unfortunately, sergey, botanists,
# Nearest to will: moravia, typeface, schellenberg, theophilus, ikeda, strict, pnv, spawning,
# Nearest to history: virgil, refresh, arbitrary, mehmet, withdraws, aberration, howie, yukio,
# Nearest to other: cancelling, daniell, oscillating, thinkers, parrish, travers, lamps, shao,
# Nearest to and: neologism, musculoskeletal, distinguished, engelbart, dividends, height, ld, cobe,
# Nearest to into: decadence, explosively, tyson, kerman, pani, fervent, adding, dilapidated,
# Nearest to time: shotgun, blues, carrot, us, avalon, estimating, mcbeal, winning,
# Nearest to years: petitioner, peacekeeping, placenta, newcomer, fit, spectacularly, jurisdictional, recanted,
# Nearest to if: chalmers, manichean, obfuscation, sympathetic, rdx, freeze, zant, olympic,
# Nearest to used: engaging, highest, hover, receive, motorbikes, islet, wainwright, noticeable,
# Average loss at step 2000 : 8.04635541236
# Average loss at step 4000 : 5.81803472114
# Average loss at step 6000 : 4.31292332453
# Average loss at step 8000 : 4.62200682759
# Average loss at step 10000 : 4.20914998144
# Nearest to during: in, against, cz, when, from, mev, tulip, pathogen,
# Nearest to for: autobahn, elucidate, of, by, touchstone, gchq, krajina, enhancing,
# Nearest to many: some, several, various, other, all, much, most, cachet,
# Nearest to two: zero, three, nine, five, six, sourceforge, gu, aoc,
# Nearest to been: become, foreknowledge, scant, polisario, newest, turkey, decomposition, outlets,
# Nearest to all: many, these, intracranial, some, religiosity, breached, sata, various,
# Nearest to he: she, it, they, who, ciconiiformes, pint, gar, herald,
# Nearest to will: would, can, must, might, should, may, cannot, to,
# Nearest to history: chesterfield, cfa, composite, composed, saxophonist, placate, spc, buck,
# Nearest to other: some, many, dayton, these, combined, jumbo, uptake, dramatic,
# Nearest to and: or, but, guest, igm, windowing, finlay, however, reconstituted,
# Nearest to into: segment, stephens, from, culprit, rare, ifvs, laing, zoltan,
# Nearest to time: proposition, dubnium, viet, year, randell, nin, suspense, surface,
# Nearest to years: year, fit, ming, universes, fate, ram, days, months,
# Nearest to if: though, about, primer, pi, mal, d, n, could,
# Nearest to used: known, called, considered, represented, islet, found, referred, brion,
# Average loss at step 12000 : 4.50981613523
# Average loss at step 14000 : 3.85354193676
# Average loss at step 16000 : 4.0101761654
# Average loss at step 18000 : 4.046809654
# Average loss at step 20000 : 5.46093836623
# Nearest to during: in, before, after, since, against, until, accusing, cca,
# Nearest to for: matchbox, when, autobahn, touchstone, extracellular, recounting, gchq, cameo,
# Nearest to many: some, several, various, these, all, numerous, certain, other,
# Nearest to two: four, one, zero, seven, garrett, basquiat, intramolecular, genghis,
# Nearest to been: become, rcito, scant, usefully, newest, him, diabetics, coincide,
# Nearest to all: various, other, different, many, arguments, battle, specific, several,
# Nearest to he: she, it, who, never, they, mother, weimar, roadie,
# Nearest to will: would, could, must, can, may, should, might, did,
# Nearest to history: sept, canyons, culture, rabindranath, composed, chesterfield, subgenres, emigr,
# Nearest to other: various, all, different, sharada, historical, many, places, both,
# Nearest to and: or, while, but, including, bradshaw, although, mcfadden, der,
# Nearest to into: from, twh, off, britannia, docking, island, douglas, healthcare,
# Nearest to time: year, wahhabi, condition, point, takashi, browsing, vermont, circulate,
# Nearest to years: days, year, times, fit, hallstatt, six, ming, katsuhiro,
# Nearest to if: where, commutative, incompatible, pozna, when, lunar, golems, vanunu,
# Nearest to used: found, seen, referred, known, designed, considered, taken, necessary,
# Average loss at step 22000 : 3.84043976092
# Average loss at step 24000 : 3.69584636706
# Average loss at step 26000 : 3.5005142754
# Average loss at step 28000 : 3.64549947435
# Average loss at step 30000 : 3.62058522338
# Nearest to during: without, when, attacking, twh, blues, belize, rhythm, lenses,
# Nearest to for: executive, eyesight, recounting, before, touchstone, gchq, affixes, worthless,
# Nearest to many: some, various, several, numerous, all, most, both, these,
# Nearest to two: lulu, baroque, several, belize, armadillo, business, lor, twh,
# Nearest to been: become, be, learner, increased, come, remained, johore, scant,
# Nearest to all: some, various, many, those, roused, both, formalization, several,
# Nearest to he: it, they, she, eventually, domestication, bofors, mother, tenses,
# Nearest to will: would, could, can, may, should, did, must, does,
# Nearest to history: emancipation, list, treatise, topics, composed, sturgeon, cloudbusting, organist,
# Nearest to other: rather, these, various, different, terraced, expectations, both, smaller,
# Nearest to and: while, or, asb, although, including, however, but, palin,
# Nearest to into: from, then, around, through, cro, docking, entities, dennett,
# Nearest to time: least, accords, end, times, choice, pani, problem, period,
# Nearest to years: days, year, months, minutes, decades, times, period, nuisance,
# Nearest to if: where, when, because, pozna, taff, though, journalistic, effected,
# Nearest to used: considered, referred, described, written, called, found, required, available,
# Average loss at step 32000 : 3.64890664712
# Average loss at step 34000 : 3.3324343603
# Average loss at step 36000 : 3.44126086479
# Average loss at step 38000 : 3.51820475924
# Average loss at step 40000 : 3.40865779976
# Nearest to during: throughout, in, after, until, within, before, despite, through,
# Nearest to for: vaux, recounting, of, autobahn, cameo, gernika, denominated, hamill,
# Nearest to many: some, several, various, numerous, most, certain, all, few,
# Nearest to two: five, several, zero, maud, some, shiki, artcyclopedia, cynics,
# Nearest to been: become, remained, come, increased, gone, rcito, be, nicosia,
# Nearest to all: both, three, israel, baroque, belize, ardennes, hbo, britannia,
# Nearest to he: she, it, they, who, bofors, sterile, there, alo,
# Nearest to will: would, could, should, must, can, may, might, cannot,
# Nearest to history: seismic, consensus, meanwhile, christened, emigr, society, vcs, episode,
# Nearest to other: various, these, rather, different, smaller, including, older, bhangra,
# Nearest to and: or, while, but, although, spate, including, venom, though,
# Nearest to into: through, across, within, from, around, fezzan, out, between,
# Nearest to time: definition, cases, gene, blues, question, same, genes, case,
# Nearest to years: months, decades, days, year, times, guises, sami, centuries,
# Nearest to if: when, where, then, because, though, sanitarium, lutes, suggest,
# Nearest to used: referred, found, considered, seen, regarded, available, described, held,
# Average loss at step 42000 : 3.56995851302
# Average loss at step 44000 : 3.45199103433
# Average loss at step 46000 : 3.54914042091
# Average loss at step 48000 : 3.31378607744
# Average loss at step 50000 : 3.23655986381
# Nearest to during: throughout, before, in, since, until, following, when, at,
# Nearest to for: involution, recounting, autobahn, after, engl, as, indeed, when,
# Nearest to many: some, several, various, numerous, all, most, certain, few,
# Nearest to two: different, nine, several, four, vitally, s, five, shiki,
# Nearest to been: remained, come, johore, become, gone, survived, already, begun,
# Nearest to all: many, several, some, puccini, various, every, most, any,
# Nearest to he: she, it, they, there, antiderivative, glossolalia, watterson, tenses,
# Nearest to will: would, could, must, can, might, cannot, may, shall,
# Nearest to history: list, presence, collection, deride, consist, form, dili, because,
# Nearest to other: various, different, others, these, mondale, rather, smaller, their,
# Nearest to and: or, while, including, but, venom, however, like, kernels,
# Nearest to into: through, across, around, within, from, between, fezzan, down,
# Nearest to time: least, activism, period, point, hyphen, year, proposition, work,
# Nearest to years: days, months, decades, centuries, year, minutes, weeks, hours,
# Nearest to if: when, where, since, though, because, while, then, toolbars,
# Nearest to used: referred, seen, available, considered, known, designed, described, classified,
# Average loss at step 52000 : 3.23602739245
# Average loss at step 54000 : 3.31130455869
# Average loss at step 56000 : 3.25488599926
# Average loss at step 58000 : 3.0096025427
# Average loss at step 60000 : 3.16187651408
# Nearest to during: throughout, before, after, until, in, following, since, within,
# Nearest to for: autobahn, without, against, after, recognizes, gernika, bushnell, nagy,
# Nearest to many: arson, belize, rare, cape, diffraction, israel, ships, lulu,
# Nearest to two: three, four, six, zero, five, ami, tubas, powerhouse,
# Nearest to been: become, come, be, remained, increased, existed, fallen, gone,
# Nearest to all: every, several, certain, settlers, hedonist, any, ret, some,
# Nearest to he: she, it, they, bofors, tetum, eventually, there, tinymud,
# Nearest to will: would, can, could, may, must, might, should, cannot,
# Nearest to history: journal, list, deride, museum, biography, seismic, origin, topics,
# Nearest to other: various, diffraction, many, antiprism, parishes, rare, lulu, european,
# Nearest to and: or, while, but, although, however, whereas, venom, including,
# Nearest to into: through, across, from, around, down, on, within, between,
# Nearest to time: point, period, hyphen, least, proposition, sickle, age, activism,
# Nearest to years: months, days, decades, year, minutes, hours, weeks, centuries,
# Nearest to if: when, where, though, then, biro, since, alfons, sanitarium,
# Nearest to used: considered, antiprism, belize, trophy, rare, ardennes, v, diffraction,
# Average loss at step 62000 : 3.16283101279
# Average loss at step 64000 : 3.17913628435
# Average loss at step 66000 : 3.41289747119
# Average loss at step 68000 : 3.16744972533
# Average loss at step 70000 : 3.20567456558
# Nearest to during: before, throughout, after, in, within, following, until, when,
# Nearest to for: without, autobahn, against, recognizes, after, hejaz, petra, if,
# Nearest to many: some, several, various, numerous, all, traditional, longbows, repaired,
# Nearest to two: three, four, several, six, cosine, ledge, zero, bazille,
# Nearest to been: become, come, remained, occurred, increased, was, survived, foreknowledge,
# Nearest to all: many, various, some, several, certain, every, numerous, both,
# Nearest to he: she, it, they, antiderivative, soybeans, glossolalia, watterson, gar,
# Nearest to will: must, should, would, could, may, can, cannot, might,
# Nearest to history: politics, reckoned, discussion, list, course, displays, popularity, reign,
# Nearest to other: various, different, these, multiple, older, others, rather, fewer,
# Nearest to and: while, or, although, though, however, hymnody, whereas, including,
# Nearest to into: across, through, from, on, around, out, via, onto,
# Nearest to time: palestinians, blues, fist, tour, pennsylvania, nothing, ships, baroque,
# Nearest to years: weeks, artists, rome, parc, honorius, centuries, rare, minorities,
# Nearest to if: when, where, fatah, then, through, minerals, operatorname, tempo,
# Nearest to used: viewed, held, designed, represented, referred, discussed, considered, seen,
# Average loss at step 72000 : 3.19015842178
# Average loss at step 74000 : 3.10256295323
# Average loss at step 76000 : 2.97069936898
# Average loss at step 78000 : 3.0682712886
# Average loss at step 80000 : 3.08588865787
# Nearest to during: before, throughout, after, until, at, in, following, despite,
# Nearest to for: after, when, gerson, without, before, toppled, simplest, soares,
# Nearest to many: some, several, various, numerous, all, both, certain, few,
# Nearest to two: arson, bigg, belize, diffraction, lulu, twh, honorius, cape,
# Nearest to been: become, come, occurred, already, increased, remained, existed, survived,
# Nearest to all: various, many, some, every, several, both, certain, numerous,
# Nearest to he: she, it, they, bofors, glossolalia, gadol, roadie, materiel,
# Nearest to will: would, must, could, can, may, should, might, cannot,
# Nearest to history: list, literature, deride, geography, society, seismic, university, timeline,
# Nearest to other: various, others, individual, different, these, fewer, older, larger,
# Nearest to and: or, but, while, although, like, hymnody, however, than,
# Nearest to into: across, through, from, out, stephens, via, gazelle, around,
# Nearest to time: activism, least, times, age, look, period, aha, expense,
# Nearest to years: decades, days, months, minutes, centuries, year, weeks, hours,
# Nearest to if: when, where, though, then, therefore, eridu, because, vacated,
# Nearest to used: referred, required, described, known, applied, considered, available, employed,
# Average loss at step 82000 : 3.13437956023
# Average loss at step 84000 : 2.95951030517
# Average loss at step 86000 : 3.02132701278
# Average loss at step 88000 : 2.99255745259
# Average loss at step 90000 : 3.03044349515
# Nearest to during: across, although, cmu, includes, over, behind, eastern, twh,
# Nearest to for: autobahn, after, petra, if, by, involution, before, secedes,
# Nearest to many: several, some, various, both, certain, thousands, most, chupacabra,
# Nearest to two: three, five, six, rhondda, yiddish, four, lessens, zero,
# Nearest to been: become, occurred, come, already, be, fallen, evolved, survived,
# Nearest to all: numerous, ten, otimes, arson, angle, some, onetime, azimuth,
# Nearest to he: she, they, it, who, bmc, roadie, already, materiel,
# Nearest to will: would, could, might, should, may, can, cannot, shall,
# Nearest to history: development, list, timeline, thicknesses, journal, correctness, licking, porting,
# Nearest to other: various, different, these, multiple, certain, commissioning, individual, uncollected,
# Nearest to and: or, including, while, etc, but, which, though, like,
# Nearest to into: through, onto, envision, within, gazelle, in, from, beyond,
# Nearest to time: period, expense, year, point, sickle, aha, bailey, dawn,
# Nearest to years: decades, months, days, centuries, minutes, weeks, generations, hours,
# Nearest to if: when, though, where, indeed, whether, within, then, because,
# Nearest to used: referred, applied, intended, required, available, seen, needed, described,
# Average loss at step 92000 : 2.97943691063
# Average loss at step 94000 : 2.90701517826
# Average loss at step 96000 : 3.00170615029
# Average loss at step 98000 : 3.06726636702
# Average loss at step 100000 : 2.74573654634
# Nearest to during: throughout, since, in, after, over, at, before, until,
# Nearest to for: after, before, autobahn, despite, arsacid, soares, cameo, against,
# Nearest to many: some, several, various, all, both, numerous, certain, thousands,
# Nearest to two: five, seven, six, bop, four, three, ten, ex,
# Nearest to been: become, occurred, come, already, fallen, remained, begun, evolved,
# Nearest to all: many, various, some, every, several, both, certain, freedmen,
# Nearest to he: she, it, they, materiel, who, company, soybeans, distressed,
# Nearest to will: would, could, should, might, can, must, may, shall,
# Nearest to history: list, biography, journal, timeline, version, literature, development, society,
# Nearest to other: earlier, various, fewer, rather, geoffroy, others, individual, commissioning,
# Nearest to and: or, but, while, including, though, although, however, whereas,
# Nearest to into: across, through, within, in, beyond, fancher, without, on,
# Nearest to time: beginning, age, least, stage, distance, distances, blues, expense,
# Nearest to years: decades, days, months, generations, weeks, minutes, hours, centuries,
# Nearest to if: danann, fatah, here, then, cluster, officially, when, satem,
# Nearest to used: referred, applied, employed, adopted, described, introduced, needed, intended,
# ['as', 'to', 'the', 'for', 'by', 'with', 'have', 'and']
# ['as', 'to', 'the', 'for', 'by', 'with', 'have', 'and']
# ['as', 'to', 'the', 'for', 'by', 'with', 'have', 'and']
# ['as', 'to', 'the', 'for', 'by', 'with', 'have', 'and']
# ['as', 'to', 'the', 'for', 'by', 'with', 'have', 'and']
# ['as', 'to', 'the', 'for', 'by', 'with', 'have', 'and']
# ['as', 'to', 'the', 'for', 'by', 'with', 'have', 'and']

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
