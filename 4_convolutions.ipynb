# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# ('Training set', (200000, 28, 28), (200000,))
# ('Validation set', (10000, 28, 28), (10000,))
# ('Test set', (10000, 28, 28), (10000,))

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# ('Training set', (200000, 28, 28, 1), (200000, 10))
# ('Validation set', (10000, 28, 28, 1), (10000, 10))
# ('Test set', (10000, 28, 28, 1), (10000, 10))

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 5.414093
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 2.011952
# Minibatch accuracy: 31.2%
# Validation accuracy: 36.8%
# Minibatch loss at step 100: 0.798234
# Minibatch accuracy: 87.5%
# Validation accuracy: 49.9%
# Minibatch loss at step 150: 0.928370
# Minibatch accuracy: 68.8%
# Validation accuracy: 56.3%
# Minibatch loss at step 200: 0.890589
# Minibatch accuracy: 81.2%
# Validation accuracy: 59.3%
# Minibatch loss at step 250: 1.224164
# Minibatch accuracy: 62.5%
# Validation accuracy: 60.4%
# Minibatch loss at step 300: 0.385372
# Minibatch accuracy: 87.5%
# Validation accuracy: 61.6%
# Minibatch loss at step 350: 0.270281
# Minibatch accuracy: 93.8%
# Validation accuracy: 62.5%
# Minibatch loss at step 400: 0.311214
# Minibatch accuracy: 93.8%
# Validation accuracy: 63.1%
# Minibatch loss at step 450: 0.713780
# Minibatch accuracy: 75.0%
# Validation accuracy: 63.8%
# Minibatch loss at step 500: 0.825620
# Minibatch accuracy: 75.0%
# Validation accuracy: 62.3%
# Minibatch loss at step 550: 0.766011
# Minibatch accuracy: 75.0%
# Validation accuracy: 63.7%
# Minibatch loss at step 600: 0.632768
# Minibatch accuracy: 75.0%
# Validation accuracy: 63.8%
# Minibatch loss at step 650: 0.488012
# Minibatch accuracy: 87.5%
# Validation accuracy: 64.5%
# Minibatch loss at step 700: 0.574701
# Minibatch accuracy: 81.2%
# Validation accuracy: 65.0%
# Minibatch loss at step 750: 0.437633
# Minibatch accuracy: 81.2%
# Validation accuracy: 66.6%
# Minibatch loss at step 800: 0.949013
# Minibatch accuracy: 75.0%
# Validation accuracy: 64.1%
# Minibatch loss at step 850: 0.509885
# Minibatch accuracy: 81.2%
# Validation accuracy: 66.2%
# Minibatch loss at step 900: 0.820185
# Minibatch accuracy: 81.2%
# Validation accuracy: 66.2%
# Minibatch loss at step 950: 0.228716
# Minibatch accuracy: 93.8%
# Validation accuracy: 64.7%
# Minibatch loss at step 1000: 0.921742
# Minibatch accuracy: 68.8%
# Validation accuracy: 66.3%
# Test accuracy: 89.2%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    hidden_mp = tf.nn.max_pool(hidden, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
    conv = tf.nn.conv2d(hidden_mp, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    hidden_mp = tf.nn.max_pool(hidden, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
    shape = hidden_mp.get_shape().as_list()
    reshape = tf.reshape(hidden_mp, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-4aa1cd068f43> in <module>()
#      43
#      44   # Training computation.
# ---> 45   logits = model(tf_train_dataset)
#      46   loss = tf.reduce_mean(
#      47     tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
#
# <ipython-input-7-4aa1cd068f43> in model(data)
#      39     shape = hidden_mp.get_shape().as_list()
#      40     # reshape = tf.reshape(hidden_mp, [shape[0], shape[1] * shape[2] * shape[3]])
# ---> 41     hidden = tf.nn.relu(tf.matmul(hidden_mp, layer3_weights) + layer3_biases)
#      42     return tf.matmul(hidden, layer4_weights) + layer4_biases
#      43
#
# /Users/jorritvandenberg/Envs/deep-learning-course/lib/python2.7/site-packages/tensorflow/python/ops/math_ops.pyc in matmul(a, b, transpose_a, transpose_b, a_is_sparse, b_is_sparse, name)
#     906                                    transpose_a=transpose_a,
#     907                                    transpose_b=transpose_b,
# --> 908                                    name=name)
#     909
#     910 sparse_matmul = gen_math_ops._sparse_mat_mul
#
# /Users/jorritvandenberg/Envs/deep-learning-course/lib/python2.7/site-packages/tensorflow/python/ops/gen_math_ops.pyc in _mat_mul(a, b, transpose_a, transpose_b, name)
#     598   """
#     599   return _op_def_lib.apply_op("MatMul", a=a, b=b, transpose_a=transpose_a,
# --> 600                               transpose_b=transpose_b, name=name)
#     601
#     602
#
# /Users/jorritvandenberg/Envs/deep-learning-course/lib/python2.7/site-packages/tensorflow/python/ops/op_def_library.pyc in apply_op(self, op_type_name, g, name, **keywords)
#     662         op = g.create_op(op_type_name, inputs, output_types, name=scope,
#     663                          input_types=input_types, attrs=attr_protos,
# --> 664                          op_def=op_def)
#     665         outputs = op.outputs
#     666         return _Restructure(ops.convert_n_to_tensor_or_indexed_slices(outputs),
#
# /Users/jorritvandenberg/Envs/deep-learning-course/lib/python2.7/site-packages/tensorflow/python/framework/ops.pyc in create_op(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_shapes)
#    1834                     original_op=self._default_original_op, op_def=op_def)
#    1835     if compute_shapes:
# -> 1836       set_shapes_for_outputs(ret)
#    1837     self._add_op(ret)
#    1838     self._record_op_seen_by_control_dependencies(ret)
#
# /Users/jorritvandenberg/Envs/deep-learning-course/lib/python2.7/site-packages/tensorflow/python/framework/ops.pyc in set_shapes_for_outputs(op)
#    1474       raise RuntimeError("No shape function registered for standard op: %s"
#    1475                          % op.type)
# -> 1476   shapes = shape_func(op)
#    1477   if len(op.outputs) != len(shapes):
#    1478     raise RuntimeError(
#
# /Users/jorritvandenberg/Envs/deep-learning-course/lib/python2.7/site-packages/tensorflow/python/ops/common_shapes.pyc in matmul_shape(op)
#      79 def matmul_shape(op):
#      80   """Shape function for a MatMul op."""
# ---> 81   a_shape = op.inputs[0].get_shape().with_rank(2)
#      82   transpose_a = op.get_attr("transpose_a")
#      83   b_shape = op.inputs[1].get_shape().with_rank(2)
#
# /Users/jorritvandenberg/Envs/deep-learning-course/lib/python2.7/site-packages/tensorflow/python/framework/tensor_shape.pyc in with_rank(self, rank)
#     597       ValueError: If `self` does not represent a shape with the given `rank`.
#     598     """
# --> 599     return self.merge_with(unknown_shape(ndims=rank))
#     600
#     601   def with_rank_at_least(self, rank):
#
# /Users/jorritvandenberg/Envs/deep-learning-course/lib/python2.7/site-packages/tensorflow/python/framework/tensor_shape.pyc in merge_with(self, other)
#     525       return other
#     526     else:
# --> 527       self.assert_same_rank(other)
#     528       new_dims = []
#     529       for i, dim in enumerate(self._dims):
#
# /Users/jorritvandenberg/Envs/deep-learning-course/lib/python2.7/site-packages/tensorflow/python/framework/tensor_shape.pyc in assert_same_rank(self, other)
#     568       if self.ndims != other.ndims:
#     569         raise ValueError(
# --> 570             "Shapes %s and %s must have the same rank" % (self, other))
#     571
#     572   def assert_has_rank(self, rank):
#
# ValueError: Shapes TensorShape([Dimension(16), Dimension(7), Dimension(7), Dimension(16)]) and TensorShape([Dimension(None), Dimension(None)]) must have the same rank

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.929922
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.054832
# Minibatch accuracy: 75.0%
# Validation accuracy: 54.0%
# Minibatch loss at step 100: 0.391433
# Minibatch accuracy: 93.8%
# Validation accuracy: 58.5%
# Minibatch loss at step 150: 1.146360
# Minibatch accuracy: 68.8%
# Validation accuracy: 58.9%
# Minibatch loss at step 200: 0.753469
# Minibatch accuracy: 68.8%
# Validation accuracy: 60.4%
# Minibatch loss at step 250: 1.090056
# Minibatch accuracy: 68.8%
# Validation accuracy: 63.6%
# Minibatch loss at step 300: 0.436127
# Minibatch accuracy: 93.8%
# Validation accuracy: 64.6%
# Minibatch loss at step 350: 0.242497
# Minibatch accuracy: 93.8%
# Validation accuracy: 62.0%
# Minibatch loss at step 400: 0.398691
# Minibatch accuracy: 87.5%
# Validation accuracy: 66.4%
# Minibatch loss at step 450: 0.710934
# Minibatch accuracy: 75.0%
# Validation accuracy: 64.6%
# Minibatch loss at step 500: 0.694463
# Minibatch accuracy: 75.0%
# Validation accuracy: 67.1%
# Minibatch loss at step 550: 0.754592
# Minibatch accuracy: 75.0%
# Validation accuracy: 65.7%
# Minibatch loss at step 600: 0.581910
# Minibatch accuracy: 87.5%
# Validation accuracy: 67.1%
# Minibatch loss at step 650: 0.473735
# Minibatch accuracy: 87.5%
# Validation accuracy: 67.6%
# Minibatch loss at step 700: 0.396362
# Minibatch accuracy: 87.5%
# Validation accuracy: 68.2%
# Minibatch loss at step 750: 0.287175
# Minibatch accuracy: 93.8%
# Validation accuracy: 68.3%
# Minibatch loss at step 800: 1.118748
# Minibatch accuracy: 75.0%
# Validation accuracy: 66.4%
# Minibatch loss at step 850: 0.578153
# Minibatch accuracy: 81.2%
# Validation accuracy: 69.5%
# Minibatch loss at step 900: 0.667590
# Minibatch accuracy: 75.0%
# Validation accuracy: 68.8%
# Minibatch loss at step 950: 0.142824
# Minibatch accuracy: 100.0%
# Validation accuracy: 69.0%
# Minibatch loss at step 1000: 1.164336
# Minibatch accuracy: 68.8%
# Validation accuracy: 70.0%
# Test accuracy: 90.3%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [image_size // 7 * image_size // 7 * depth, num_hidden], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer5_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer5_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data, training):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    hidden_mp = tf.nn.max_pool(hidden, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
    conv = tf.nn.conv2d(hidden_mp, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    hidden_mp = tf.nn.max_pool(hidden, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
    conv = tf.nn.conv2d(hidden_mp, layer3_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer3_biases)
    hidden_mp = tf.nn.max_pool(hidden, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME') 
    shape = hidden_mp.get_shape().as_list()
    reshape = tf.reshape(hidden_mp, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer4_weights) + layer4_biases)
    
    if training:
        hidden_drop = tf.nn.dropout(hidden, 0.5)
        
    return tf.matmul(hidden, layer5_weights) + layer5_biases
  
  # Training computation.
  logits = model(tf_train_dataset, True)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  # optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Optimizer with learning rate decay.
  global_step = tf.Variable(0, trainable=False)
  starter_learning_rate = 0.1
  learning_rate = tf.train.exponential_decay(starter_learning_rate, global_step,
                                           100000, 0.96, staircase=True)
    
  optimizer = tf.train.AdagradOptimizer(learning_rate).minimize(loss, global_step=global_step)

  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset, False))
  test_prediction = tf.nn.softmax(model(tf_test_dataset, False))

# %%
num_steps = 50001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 2.667387
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 2.309677
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 100: 2.308176
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 150: 2.283745
# Minibatch accuracy: 18.8%
# Validation accuracy: 10.0%
# Minibatch loss at step 200: 2.305626
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 250: 2.317306
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 300: 2.323164
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 350: 2.318958
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 400: 2.303871
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 450: 2.310688
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 500: 2.315220
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 550: 2.307732
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 600: 2.293321
# Minibatch accuracy: 25.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 650: 2.302015
# Minibatch accuracy: 18.8%
# Validation accuracy: 10.0%
# Minibatch loss at step 700: 2.310921
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 750: 2.299582
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 800: 2.305992
# Minibatch accuracy: 18.8%
# Validation accuracy: 10.0%
# Minibatch loss at step 850: 2.327377
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 900: 2.311970
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 950: 2.321998
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 1000: 2.318867
# Minibatch accuracy: 18.8%
# Validation accuracy: 10.0%
# Minibatch loss at step 1050: 2.288272
# Minibatch accuracy: 18.8%
# Validation accuracy: 10.0%
# Minibatch loss at step 1100: 2.311800
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 1150: 2.289844
# Minibatch accuracy: 18.8%
# Validation accuracy: 10.0%
# Minibatch loss at step 1200: 2.318099
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 1250: 2.296842
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 1300: 2.315431
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 1350: 2.298502
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 1400: 2.315429
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 1450: 2.310918
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 1500: 2.288681
# Minibatch accuracy: 18.8%
# Validation accuracy: 10.0%
# Minibatch loss at step 1550: 2.297909
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 1600: 2.299839
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 1650: 2.318420
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 1700: 2.322555
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 1750: 2.293746
# Minibatch accuracy: 18.8%
# Validation accuracy: 10.0%
# Minibatch loss at step 1800: 2.298838
# Minibatch accuracy: 25.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 1850: 2.310233
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 1900: 2.310375
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 1950: 2.308534
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 2000: 2.292462
# Minibatch accuracy: 25.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 2050: 2.310136
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 2100: 2.313293
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 2150: 2.291014
# Minibatch accuracy: 6.2%
# Validation accuracy: 12.3%
# Minibatch loss at step 2200: 2.108654
# Minibatch accuracy: 18.8%
# Validation accuracy: 21.1%
# Minibatch loss at step 2250: 1.336849
# Minibatch accuracy: 50.0%
# Validation accuracy: 42.7%
# Minibatch loss at step 2300: 0.411082
# Minibatch accuracy: 87.5%
# Validation accuracy: 54.0%
# Minibatch loss at step 2350: 0.806084
# Minibatch accuracy: 75.0%
# Validation accuracy: 48.7%
# Minibatch loss at step 2400: 0.724239
# Minibatch accuracy: 81.2%
# Validation accuracy: 58.0%
# Minibatch loss at step 2450: 0.755902
# Minibatch accuracy: 81.2%
# Validation accuracy: 59.6%
# Minibatch loss at step 2500: 0.206644
# Minibatch accuracy: 100.0%
# Validation accuracy: 60.5%
# Minibatch loss at step 2550: 0.795673
# Minibatch accuracy: 81.2%
# Validation accuracy: 59.5%
# Minibatch loss at step 2600: 0.167055
# Minibatch accuracy: 93.8%
# Validation accuracy: 62.8%
# Minibatch loss at step 2650: 0.338285
# Minibatch accuracy: 87.5%
# Validation accuracy: 66.2%
# Minibatch loss at step 2700: 1.175237
# Minibatch accuracy: 62.5%
# Validation accuracy: 66.1%
# Minibatch loss at step 2750: 0.065882
# Minibatch accuracy: 100.0%
# Validation accuracy: 66.9%
# Minibatch loss at step 2800: 0.933174
# Minibatch accuracy: 68.8%
# Validation accuracy: 67.6%
# Minibatch loss at step 2850: 0.686369
# Minibatch accuracy: 75.0%
# Validation accuracy: 68.9%
# Minibatch loss at step 2900: 0.653186
# Minibatch accuracy: 68.8%
# Validation accuracy: 69.4%
# Minibatch loss at step 2950: 0.423585
# Minibatch accuracy: 87.5%
# Validation accuracy: 69.0%
# Minibatch loss at step 3000: 0.310445
# Minibatch accuracy: 93.8%
# Validation accuracy: 70.3%
# Minibatch loss at step 3050: 0.294812
# Minibatch accuracy: 87.5%
# Validation accuracy: 68.8%
# Minibatch loss at step 3100: 0.762526
# Minibatch accuracy: 81.2%
# Validation accuracy: 69.4%
# Minibatch loss at step 3150: 0.703842
# Minibatch accuracy: 75.0%
# Validation accuracy: 70.8%
# Minibatch loss at step 3200: 0.663704
# Minibatch accuracy: 81.2%
# Validation accuracy: 70.3%
# Minibatch loss at step 3250: 0.141123
# Minibatch accuracy: 100.0%
# Validation accuracy: 70.9%
# Minibatch loss at step 3300: 0.507898
# Minibatch accuracy: 81.2%
# Validation accuracy: 71.6%
# Minibatch loss at step 3350: 0.382453
# Minibatch accuracy: 87.5%
# Validation accuracy: 70.5%
# Minibatch loss at step 3400: 0.157390
# Minibatch accuracy: 93.8%
# Validation accuracy: 72.4%
# Minibatch loss at step 3450: 0.245829
# Minibatch accuracy: 93.8%
# Validation accuracy: 72.6%
# Minibatch loss at step 3500: 0.489185
# Minibatch accuracy: 87.5%
# Validation accuracy: 71.8%
# Minibatch loss at step 3550: 0.393267
# Minibatch accuracy: 81.2%
# Validation accuracy: 71.4%
# Minibatch loss at step 3600: 0.324063
# Minibatch accuracy: 87.5%
# Validation accuracy: 71.4%
# Minibatch loss at step 3650: 0.355348
# Minibatch accuracy: 93.8%
# Validation accuracy: 72.0%
# Minibatch loss at step 3700: 0.467703
# Minibatch accuracy: 87.5%
# Validation accuracy: 72.6%
# Minibatch loss at step 3750: 0.304816
# Minibatch accuracy: 87.5%
# Validation accuracy: 71.5%
# Minibatch loss at step 3800: 0.133088
# Minibatch accuracy: 93.8%
# Validation accuracy: 72.7%
# Minibatch loss at step 3850: 0.037984
# Minibatch accuracy: 100.0%
# Validation accuracy: 72.2%
# Minibatch loss at step 3900: 0.229621
# Minibatch accuracy: 93.8%
# Validation accuracy: 73.5%
# Minibatch loss at step 3950: 0.419839
# Minibatch accuracy: 87.5%
# Validation accuracy: 72.9%
# Minibatch loss at step 4000: 1.174180
# Minibatch accuracy: 68.8%
# Validation accuracy: 73.5%
# Minibatch loss at step 4050: 0.063263
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.2%
# Minibatch loss at step 4100: 0.406533
# Minibatch accuracy: 81.2%
# Validation accuracy: 72.2%
# Minibatch loss at step 4150: 0.422434
# Minibatch accuracy: 81.2%
# Validation accuracy: 71.4%
# Minibatch loss at step 4200: 0.211380
# Minibatch accuracy: 93.8%
# Validation accuracy: 73.2%
# Minibatch loss at step 4250: 0.230802
# Minibatch accuracy: 93.8%
# Validation accuracy: 70.6%
# Minibatch loss at step 4300: 0.167292
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.0%
# Minibatch loss at step 4350: 0.260590
# Minibatch accuracy: 93.8%
# Validation accuracy: 73.4%
# Minibatch loss at step 4400: 0.344619
# Minibatch accuracy: 87.5%
# Validation accuracy: 74.0%
# Minibatch loss at step 4450: 0.456518
# Minibatch accuracy: 87.5%
# Validation accuracy: 73.3%
# Minibatch loss at step 4500: 0.427613
# Minibatch accuracy: 87.5%
# Validation accuracy: 74.0%
# Minibatch loss at step 4550: 0.258059
# Minibatch accuracy: 93.8%
# Validation accuracy: 73.2%
# Minibatch loss at step 4600: 0.254793
# Minibatch accuracy: 87.5%
# Validation accuracy: 72.9%
# Minibatch loss at step 4650: 0.419242
# Minibatch accuracy: 87.5%
# Validation accuracy: 72.8%
# Minibatch loss at step 4700: 0.234539
# Minibatch accuracy: 93.8%
# Validation accuracy: 74.4%
# Minibatch loss at step 4750: 0.177742
# Minibatch accuracy: 93.8%
# Validation accuracy: 74.3%
# Minibatch loss at step 4800: 0.349169
# Minibatch accuracy: 87.5%
# Validation accuracy: 73.2%
# Minibatch loss at step 4850: 0.513120
# Minibatch accuracy: 81.2%
# Validation accuracy: 74.2%
# Minibatch loss at step 4900: 0.493960
# Minibatch accuracy: 87.5%
# Validation accuracy: 74.5%
# Minibatch loss at step 4950: 0.502971
# Minibatch accuracy: 87.5%
# Validation accuracy: 75.0%
# Minibatch loss at step 5000: 0.367556
# Minibatch accuracy: 87.5%
# Validation accuracy: 75.1%
# Minibatch loss at step 5050: 0.059235
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.8%
# Minibatch loss at step 5100: 0.263995
# Minibatch accuracy: 93.8%
# Validation accuracy: 73.2%
# Minibatch loss at step 5150: 0.248239
# Minibatch accuracy: 93.8%
# Validation accuracy: 75.1%
# Minibatch loss at step 5200: 0.295674
# Minibatch accuracy: 87.5%
# Validation accuracy: 74.9%
# Minibatch loss at step 5250: 0.192944
# Minibatch accuracy: 100.0%
# Validation accuracy: 74.9%
# Minibatch loss at step 5300: 0.188799
# Minibatch accuracy: 93.8%
# Validation accuracy: 73.2%
# Minibatch loss at step 5350: 1.079768
# Minibatch accuracy: 75.0%
# Validation accuracy: 74.3%
# Minibatch loss at step 5400: 0.205731
# Minibatch accuracy: 87.5%
# Validation accuracy: 74.4%
# Minibatch loss at step 5450: 0.389999
# Minibatch accuracy: 87.5%
# Validation accuracy: 74.2%
# Minibatch loss at step 5500: 0.736578
# Minibatch accuracy: 81.2%
# Validation accuracy: 74.8%
# Minibatch loss at step 5550: 0.204164
# Minibatch accuracy: 93.8%
# Validation accuracy: 74.8%
# Minibatch loss at step 5600: 0.175758
# Minibatch accuracy: 93.8%
# Validation accuracy: 75.3%
# Minibatch loss at step 5650: 1.064162
# Minibatch accuracy: 62.5%
# Validation accuracy: 74.1%
# Minibatch loss at step 5700: 0.285199
# Minibatch accuracy: 100.0%
# Validation accuracy: 75.3%
# Minibatch loss at step 5750: 0.289556
# Minibatch accuracy: 87.5%
# Validation accuracy: 75.2%
# Minibatch loss at step 5800: 0.344602
# Minibatch accuracy: 87.5%
# Validation accuracy: 74.5%
# Minibatch loss at step 5850: 0.197440
# Minibatch accuracy: 93.8%
# Validation accuracy: 75.2%
# Minibatch loss at step 5900: 0.275002
# Minibatch accuracy: 93.8%
# Validation accuracy: 74.9%
# Minibatch loss at step 5950: 0.260748
# Minibatch accuracy: 93.8%
# Validation accuracy: 74.4%
# Minibatch loss at step 6000: 0.211242
# Minibatch accuracy: 93.8%
# Validation accuracy: 75.8%
# Minibatch loss at step 6050: 0.175529
# Minibatch accuracy: 93.8%
# Validation accuracy: 75.6%
# Minibatch loss at step 6100: 0.483254
# Minibatch accuracy: 93.8%
# Validation accuracy: 74.8%
# Minibatch loss at step 6150: 0.487422
# Minibatch accuracy: 81.2%
# Validation accuracy: 75.5%
# Minibatch loss at step 6200: 0.516665
# Minibatch accuracy: 81.2%
# Validation accuracy: 75.6%
# Minibatch loss at step 6250: 0.143556
# Minibatch accuracy: 100.0%
# Validation accuracy: 76.5%
# Minibatch loss at step 6300: 0.391829
# Minibatch accuracy: 93.8%
# Validation accuracy: 75.8%
# Minibatch loss at step 6350: 0.179973
# Minibatch accuracy: 93.8%
# Validation accuracy: 76.6%
# Minibatch loss at step 6400: 0.149485
# Minibatch accuracy: 93.8%
# Validation accuracy: 75.8%
# Minibatch loss at step 6450: 0.116044
# Minibatch accuracy: 100.0%
# Validation accuracy: 76.7%
# Minibatch loss at step 6500: 0.809001
# Minibatch accuracy: 75.0%
# Validation accuracy: 73.2%
# Minibatch loss at step 6550: 0.210192
# Minibatch accuracy: 100.0%
# Validation accuracy: 76.8%
# Minibatch loss at step 6600: 0.360181
# Minibatch accuracy: 87.5%
# Validation accuracy: 76.7%
# Minibatch loss at step 6650: 0.405828
# Minibatch accuracy: 81.2%
# Validation accuracy: 76.7%
# Minibatch loss at step 6700: 0.067822
# Minibatch accuracy: 100.0%
# Validation accuracy: 76.1%
# Minibatch loss at step 6750: 0.525884
# Minibatch accuracy: 81.2%
# Validation accuracy: 75.0%
# Minibatch loss at step 6800: 0.167564
# Minibatch accuracy: 93.8%
# Validation accuracy: 76.2%
# Minibatch loss at step 6850: 0.059014
# Minibatch accuracy: 100.0%
# Validation accuracy: 76.3%
# Minibatch loss at step 6900: 0.331952
# Minibatch accuracy: 87.5%
# Validation accuracy: 76.8%
# Minibatch loss at step 6950: 0.071650
# Minibatch accuracy: 100.0%
# Validation accuracy: 75.6%
# Minibatch loss at step 7000: 0.087074
# Minibatch accuracy: 100.0%
# Validation accuracy: 76.3%
# Minibatch loss at step 7050: 0.164793
# Minibatch accuracy: 93.8%
# Validation accuracy: 75.8%
# Minibatch loss at step 7100: 0.576995
# Minibatch accuracy: 81.2%
# Validation accuracy: 76.0%
# Minibatch loss at step 7150: 0.198983
# Minibatch accuracy: 100.0%
# Validation accuracy: 76.4%
# Minibatch loss at step 7200: 0.171739
# Minibatch accuracy: 93.8%
# Validation accuracy: 75.7%
# Minibatch loss at step 7250: 0.133461
# Minibatch accuracy: 93.8%
# Validation accuracy: 76.2%
# Minibatch loss at step 7300: 0.576444
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.2%
# Minibatch loss at step 7350: 0.071502
# Minibatch accuracy: 100.0%
# Validation accuracy: 76.1%
# Minibatch loss at step 7400: 0.321186
# Minibatch accuracy: 87.5%
# Validation accuracy: 76.6%
# Minibatch loss at step 7450: 0.309552
# Minibatch accuracy: 87.5%
# Validation accuracy: 76.7%
# Minibatch loss at step 7500: 0.146036
# Minibatch accuracy: 93.8%
# Validation accuracy: 76.8%
# Minibatch loss at step 7550: 0.511740
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.1%
# Minibatch loss at step 7600: 0.439449
# Minibatch accuracy: 81.2%
# Validation accuracy: 75.4%
# Minibatch loss at step 7650: 0.160438
# Minibatch accuracy: 93.8%
# Validation accuracy: 76.3%
# Minibatch loss at step 7700: 0.246272
# Minibatch accuracy: 93.8%
# Validation accuracy: 76.2%
# Minibatch loss at step 7750: 0.205298
# Minibatch accuracy: 93.8%
# Validation accuracy: 75.6%
# Minibatch loss at step 7800: 0.094305
# Minibatch accuracy: 100.0%
# Validation accuracy: 76.9%
# Minibatch loss at step 7850: 1.122845
# Minibatch accuracy: 87.5%
# Validation accuracy: 76.1%
# Minibatch loss at step 7900: 0.615893
# Minibatch accuracy: 81.2%
# Validation accuracy: 76.3%
# Minibatch loss at step 7950: 0.511556
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.4%
# Minibatch loss at step 8000: 0.294948
# Minibatch accuracy: 87.5%
# Validation accuracy: 76.8%
# Minibatch loss at step 8050: 0.500668
# Minibatch accuracy: 87.5%
# Validation accuracy: 76.6%
# Minibatch loss at step 8100: 0.082539
# Minibatch accuracy: 100.0%
# Validation accuracy: 77.0%
# Minibatch loss at step 8150: 0.240752
# Minibatch accuracy: 93.8%
# Validation accuracy: 76.0%
# Minibatch loss at step 8200: 0.221843
# Minibatch accuracy: 93.8%
# Validation accuracy: 76.8%
# Minibatch loss at step 8250: 0.250778
# Minibatch accuracy: 87.5%
# Validation accuracy: 76.5%
# Minibatch loss at step 8300: 0.165008
# Minibatch accuracy: 93.8%
# Validation accuracy: 76.5%
# Minibatch loss at step 8350: 0.781957
# Minibatch accuracy: 75.0%
# Validation accuracy: 76.4%
# Minibatch loss at step 8400: 0.144188
# Minibatch accuracy: 93.8%
# Validation accuracy: 76.0%
# Minibatch loss at step 8450: 0.117590
# Minibatch accuracy: 100.0%
# Validation accuracy: 77.3%
# Minibatch loss at step 8500: 0.416913
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.6%
# Minibatch loss at step 8550: 0.554348
# Minibatch accuracy: 81.2%
# Validation accuracy: 76.8%
# Minibatch loss at step 8600: 0.577160
# Minibatch accuracy: 75.0%
# Validation accuracy: 76.4%
# Minibatch loss at step 8650: 0.220236
# Minibatch accuracy: 93.8%
# Validation accuracy: 76.3%
# Minibatch loss at step 8700: 0.489185
# Minibatch accuracy: 87.5%
# Validation accuracy: 76.6%
# Minibatch loss at step 8750: 0.631630
# Minibatch accuracy: 75.0%
# Validation accuracy: 76.3%
# Minibatch loss at step 8800: 0.892199
# Minibatch accuracy: 62.5%
# Validation accuracy: 76.9%
# Minibatch loss at step 8850: 0.255546
# Minibatch accuracy: 93.8%
# Validation accuracy: 77.7%
# Minibatch loss at step 8900: 0.191245
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.0%
# Minibatch loss at step 8950: 0.180100
# Minibatch accuracy: 93.8%
# Validation accuracy: 77.0%
# Minibatch loss at step 9000: 0.316198
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.1%
# Minibatch loss at step 9050: 0.345264
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.3%
# Minibatch loss at step 9100: 0.537723
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.0%
# Minibatch loss at step 9150: 0.845830
# Minibatch accuracy: 68.8%
# Validation accuracy: 76.4%
# Minibatch loss at step 9200: 0.019044
# Minibatch accuracy: 100.0%
# Validation accuracy: 77.4%
# Minibatch loss at step 9250: 0.339328
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.8%
# Minibatch loss at step 9300: 0.175969
# Minibatch accuracy: 93.8%
# Validation accuracy: 77.5%
# Minibatch loss at step 9350: 0.775562
# Minibatch accuracy: 75.0%
# Validation accuracy: 76.6%
# Minibatch loss at step 9400: 0.185136
# Minibatch accuracy: 93.8%
# Validation accuracy: 76.8%
# Minibatch loss at step 9450: 1.168532
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.4%
# Minibatch loss at step 9500: 0.955188
# Minibatch accuracy: 93.8%
# Validation accuracy: 77.7%
# Minibatch loss at step 9550: 0.705983
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.3%
# Minibatch loss at step 9600: 0.295425
# Minibatch accuracy: 87.5%
# Validation accuracy: 76.2%
# Minibatch loss at step 9650: 0.102832
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.1%
# Minibatch loss at step 9700: 0.617414
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.6%
# Minibatch loss at step 9750: 0.389842
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.6%
# Minibatch loss at step 9800: 0.013145
# Minibatch accuracy: 100.0%
# Validation accuracy: 77.7%
# Minibatch loss at step 9850: 0.173165
# Minibatch accuracy: 93.8%
# Validation accuracy: 77.6%
# Minibatch loss at step 9900: 0.412495
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.5%
# Minibatch loss at step 9950: 0.267327
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.8%
# Minibatch loss at step 10000: 0.096315
# Minibatch accuracy: 100.0%
# Validation accuracy: 77.5%
# Minibatch loss at step 10050: 0.369408
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.4%
# Minibatch loss at step 10100: 0.376278
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.4%
# Minibatch loss at step 10150: 0.118100
# Minibatch accuracy: 100.0%
# Validation accuracy: 77.3%
# Minibatch loss at step 10200: 0.006811
# Minibatch accuracy: 100.0%
# Validation accuracy: 77.4%
# Minibatch loss at step 10250: 0.385247
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.2%
# Minibatch loss at step 10300: 0.084695
# Minibatch accuracy: 93.8%
# Validation accuracy: 77.8%
# Minibatch loss at step 10350: 0.219179
# Minibatch accuracy: 93.8%
# Validation accuracy: 77.8%
# Minibatch loss at step 10400: 0.293063
# Minibatch accuracy: 93.8%
# Validation accuracy: 77.3%
# Minibatch loss at step 10450: 0.175108
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.1%
# Minibatch loss at step 10500: 0.469877
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.8%
# Minibatch loss at step 10550: 0.645508
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.9%
# Minibatch loss at step 10600: 0.433059
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.0%
# Minibatch loss at step 10650: 0.736995
# Minibatch accuracy: 93.8%
# Validation accuracy: 77.2%
# Minibatch loss at step 10700: 0.034418
# Minibatch accuracy: 100.0%
# Validation accuracy: 77.7%
# Minibatch loss at step 10750: 0.565336
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.5%
# Minibatch loss at step 10800: 0.334444
# Minibatch accuracy: 93.8%
# Validation accuracy: 77.8%
# Minibatch loss at step 10850: 0.150386
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.1%
# Minibatch loss at step 10900: 0.714095
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.1%
# Minibatch loss at step 10950: 0.144248
# Minibatch accuracy: 93.8%
# Validation accuracy: 77.7%
# Minibatch loss at step 11000: 0.333594
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.8%
# Minibatch loss at step 11050: 0.480908
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.1%
# Minibatch loss at step 11100: 0.255073
# Minibatch accuracy: 93.8%
# Validation accuracy: 77.8%
# Minibatch loss at step 11150: 0.736304
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.0%
# Minibatch loss at step 11200: 0.471586
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.9%
# Minibatch loss at step 11250: 0.047599
# Minibatch accuracy: 100.0%
# Validation accuracy: 77.9%
# Minibatch loss at step 11300: 0.601843
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.9%
# Minibatch loss at step 11350: 0.084224
# Minibatch accuracy: 100.0%
# Validation accuracy: 76.7%
# Minibatch loss at step 11400: 0.548817
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.9%
# Minibatch loss at step 11450: 0.472134
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.8%
# Minibatch loss at step 11500: 0.045493
# Minibatch accuracy: 100.0%
# Validation accuracy: 77.7%
# Minibatch loss at step 11550: 0.090524
# Minibatch accuracy: 100.0%
# Validation accuracy: 78.4%
# Minibatch loss at step 11600: 0.552229
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.1%
# Minibatch loss at step 11650: 0.376631
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.4%
# Minibatch loss at step 11700: 0.300983
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.2%
# Minibatch loss at step 11750: 0.709957
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.7%
# Minibatch loss at step 11800: 0.299100
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.4%
# Minibatch loss at step 11850: 0.023565
# Minibatch accuracy: 100.0%
# Validation accuracy: 78.2%
# Minibatch loss at step 11900: 0.449409
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.1%
# Minibatch loss at step 11950: 0.337492
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.3%
# Minibatch loss at step 12000: 0.959774
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.4%
# Minibatch loss at step 12050: 0.114775
# Minibatch accuracy: 100.0%
# Validation accuracy: 77.7%
# Minibatch loss at step 12100: 0.135210
# Minibatch accuracy: 93.8%
# Validation accuracy: 77.6%
# Minibatch loss at step 12150: 0.157361
# Minibatch accuracy: 93.8%
# Validation accuracy: 77.7%
# Minibatch loss at step 12200: 0.272083
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.4%
# Minibatch loss at step 12250: 0.139271
# Minibatch accuracy: 93.8%
# Validation accuracy: 77.9%
# Minibatch loss at step 12300: 0.213117
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.3%
# Minibatch loss at step 12350: 0.297277
# Minibatch accuracy: 93.8%
# Validation accuracy: 77.1%
# Minibatch loss at step 12400: 0.437670
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.8%
# Minibatch loss at step 12450: 0.621688
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.5%
# Minibatch loss at step 12500: 0.211729
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.3%
# Minibatch loss at step 12550: 0.388219
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.2%
# Minibatch loss at step 12600: 0.232243
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.2%
# Minibatch loss at step 12650: 0.433096
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.8%
# Minibatch loss at step 12700: 0.614754
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.1%
# Minibatch loss at step 12750: 0.155441
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.4%
# Minibatch loss at step 12800: 0.348182
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.1%
# Minibatch loss at step 12850: 0.783203
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.5%
# Minibatch loss at step 12900: 0.068500
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.4%
# Minibatch loss at step 12950: 0.272250
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.9%
# Minibatch loss at step 13000: 0.474102
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.1%
# Minibatch loss at step 13050: 0.382016
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.3%
# Minibatch loss at step 13100: 0.341123
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.4%
# Minibatch loss at step 13150: 0.022595
# Minibatch accuracy: 100.0%
# Validation accuracy: 78.5%
# Minibatch loss at step 13200: 0.079713
# Minibatch accuracy: 100.0%
# Validation accuracy: 78.1%
# Minibatch loss at step 13250: 0.443325
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.6%
# Minibatch loss at step 13300: 0.171417
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.1%
# Minibatch loss at step 13350: 0.202450
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.6%
# Minibatch loss at step 13400: 0.341128
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.6%
# Minibatch loss at step 13450: 0.106758
# Minibatch accuracy: 100.0%
# Validation accuracy: 78.2%
# Minibatch loss at step 13500: 1.017129
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.5%
# Minibatch loss at step 13550: 0.288724
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.0%
# Minibatch loss at step 13600: 0.326862
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.4%
# Minibatch loss at step 13650: 0.684608
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.8%
# Minibatch loss at step 13700: 0.222463
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.2%
# Minibatch loss at step 13750: 0.753832
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.9%
# Minibatch loss at step 13800: 0.711668
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.0%
# Minibatch loss at step 13850: 0.113431
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.9%
# Minibatch loss at step 13900: 0.025801
# Minibatch accuracy: 100.0%
# Validation accuracy: 78.6%
# Minibatch loss at step 13950: 0.328511
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.3%
# Minibatch loss at step 14000: 0.510133
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.2%
# Minibatch loss at step 14050: 0.107064
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.4%
# Minibatch loss at step 14100: 0.196926
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.0%
# Minibatch loss at step 14150: 0.445919
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.7%
# Minibatch loss at step 14200: 0.156280
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.2%
# Minibatch loss at step 14250: 0.342194
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.6%
# Minibatch loss at step 14300: 0.068735
# Minibatch accuracy: 100.0%
# Validation accuracy: 78.8%
# Minibatch loss at step 14350: 0.168469
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.8%
# Minibatch loss at step 14400: 0.309086
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.6%
# Minibatch loss at step 14450: 0.366067
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.7%
# Minibatch loss at step 14500: 0.411484
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.4%
# Minibatch loss at step 14550: 0.156577
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.2%
# Minibatch loss at step 14600: 0.163925
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.1%
# Minibatch loss at step 14650: 0.219302
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.0%
# Minibatch loss at step 14700: 0.085016
# Minibatch accuracy: 100.0%
# Validation accuracy: 78.8%
# Minibatch loss at step 14750: 0.438560
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.5%
# Minibatch loss at step 14800: 0.277401
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.7%
# Minibatch loss at step 14850: 0.110789
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.5%
# Minibatch loss at step 14900: 0.679426
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.6%
# Minibatch loss at step 14950: 0.428098
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.2%
# Minibatch loss at step 15000: 0.136699
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.6%
# Minibatch loss at step 15050: 0.055316
# Minibatch accuracy: 100.0%
# Validation accuracy: 77.8%
# Minibatch loss at step 15100: 0.125954
# Minibatch accuracy: 100.0%
# Validation accuracy: 78.6%
# Minibatch loss at step 15150: 0.255175
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.6%
# Minibatch loss at step 15200: 0.035860
# Minibatch accuracy: 100.0%
# Validation accuracy: 78.7%
# Minibatch loss at step 15250: 0.425411
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.5%
# Minibatch loss at step 15300: 0.496549
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.4%
# Minibatch loss at step 15350: 0.276572
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.2%
# Minibatch loss at step 15400: 0.522254
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.4%
# Minibatch loss at step 15450: 0.369657
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.8%
# Minibatch loss at step 15500: 0.093754
# Minibatch accuracy: 100.0%
# Validation accuracy: 78.6%
# Minibatch loss at step 15550: 0.007606
# Minibatch accuracy: 100.0%
# Validation accuracy: 78.7%
# Minibatch loss at step 15600: 0.014448
# Minibatch accuracy: 100.0%
# Validation accuracy: 78.6%
# Minibatch loss at step 15650: 0.344318
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.5%
# Minibatch loss at step 15700: 0.621075
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.2%
# Minibatch loss at step 15750: 0.189522
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.9%
# Minibatch loss at step 15800: 0.071883
# Minibatch accuracy: 100.0%
# Validation accuracy: 78.8%
# Minibatch loss at step 15850: 0.213124
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.6%
# Minibatch loss at step 15900: 0.095122
# Minibatch accuracy: 100.0%
# Validation accuracy: 78.4%
# Minibatch loss at step 15950: 0.303744
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.1%
# Minibatch loss at step 16000: 0.151756
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.8%
# Minibatch loss at step 16050: 0.325202
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.4%
# Minibatch loss at step 16100: 0.329098
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.4%
# Minibatch loss at step 16150: 0.153983
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.2%
# Minibatch loss at step 16200: 0.121915
# Minibatch accuracy: 100.0%
# Validation accuracy: 78.0%
# Minibatch loss at step 16250: 0.062927
# Minibatch accuracy: 100.0%
# Validation accuracy: 78.7%
# Minibatch loss at step 16300: 0.631441
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.1%
# Minibatch loss at step 16350: 1.476119
# Minibatch accuracy: 62.5%
# Validation accuracy: 78.3%
# Minibatch loss at step 16400: 0.334599
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.0%
# Minibatch loss at step 16450: 0.058659
# Minibatch accuracy: 100.0%
# Validation accuracy: 78.4%
# Minibatch loss at step 16500: 0.075757
# Minibatch accuracy: 100.0%
# Validation accuracy: 78.8%
# Minibatch loss at step 16550: 0.576577
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.7%
# Minibatch loss at step 16600: 0.009356
# Minibatch accuracy: 100.0%
# Validation accuracy: 77.1%
# Minibatch loss at step 16650: 0.205179
# Minibatch accuracy: 93.8%
# Validation accuracy: 77.2%
# Minibatch loss at step 16700: 0.115870
# Minibatch accuracy: 100.0%
# Validation accuracy: 78.4%
# Minibatch loss at step 16750: 0.124200
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.0%
# Minibatch loss at step 16800: 0.288711
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.3%
# Minibatch loss at step 16850: 0.165100
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.0%
# Minibatch loss at step 16900: 0.258295
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.4%
# Minibatch loss at step 16950: 0.199775
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.9%
# Minibatch loss at step 17000: 0.471110
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.8%
# Minibatch loss at step 17050: 0.303082
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.3%
# Minibatch loss at step 17100: 0.536513
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.5%
# Minibatch loss at step 17150: 0.218217
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.4%
# Minibatch loss at step 17200: 0.043506
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.3%
# Minibatch loss at step 17250: 0.146308
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.0%
# Minibatch loss at step 17300: 0.320239
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.9%
# Minibatch loss at step 17350: 0.422859
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.8%
# Minibatch loss at step 17400: 0.112222
# Minibatch accuracy: 100.0%
# Validation accuracy: 78.9%
# Minibatch loss at step 17450: 0.009727
# Minibatch accuracy: 100.0%
# Validation accuracy: 78.7%
# Minibatch loss at step 17500: 0.144001
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.0%
# Minibatch loss at step 17550: 0.725318
# Minibatch accuracy: 68.8%
# Validation accuracy: 79.1%
# Minibatch loss at step 17600: 0.579445
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.9%
# Minibatch loss at step 17650: 0.008638
# Minibatch accuracy: 100.0%
# Validation accuracy: 78.9%
# Minibatch loss at step 17700: 0.332688
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.7%
# Minibatch loss at step 17750: 0.510747
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.2%
# Minibatch loss at step 17800: 0.368811
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.9%
# Minibatch loss at step 17850: 0.400482
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.0%
# Minibatch loss at step 17900: 0.434044
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.8%
# Minibatch loss at step 17950: 0.327032
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.7%
# Minibatch loss at step 18000: 0.102133
# Minibatch accuracy: 100.0%
# Validation accuracy: 78.5%
# Minibatch loss at step 18050: 0.325471
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.9%
# Minibatch loss at step 18100: 0.425236
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.1%
# Minibatch loss at step 18150: 0.408013
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.0%
# Minibatch loss at step 18200: 0.822407
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.2%
# Minibatch loss at step 18250: 0.391558
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.7%
# Minibatch loss at step 18300: 0.239395
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.4%
# Minibatch loss at step 18350: 0.018748
# Minibatch accuracy: 100.0%
# Validation accuracy: 78.7%
# Minibatch loss at step 18400: 0.288076
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.8%
# Minibatch loss at step 18450: 0.305213
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.8%
# Minibatch loss at step 18500: 0.188720
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.6%
# Minibatch loss at step 18550: 0.292679
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.7%
# Minibatch loss at step 18600: 1.688622
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.7%
# Minibatch loss at step 18650: 0.635096
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.6%
# Minibatch loss at step 18700: 0.250118
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.9%
# Minibatch loss at step 18750: 0.434626
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.8%
# Minibatch loss at step 18800: 0.362422
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.3%
# Minibatch loss at step 18850: 0.063557
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.1%
# Minibatch loss at step 18900: 0.586890
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.1%
# Minibatch loss at step 18950: 0.076538
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.2%
# Minibatch loss at step 19000: 0.127732
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.0%
# Minibatch loss at step 19050: 0.317726
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.4%
# Minibatch loss at step 19100: 0.265160
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.4%
# Minibatch loss at step 19150: 0.693631
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.2%
# Minibatch loss at step 19200: 0.207375
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.4%
# Minibatch loss at step 19250: 0.329395
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.9%
# Minibatch loss at step 19300: 0.204033
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.6%
# Minibatch loss at step 19350: 0.218036
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.7%
# Minibatch loss at step 19400: 0.113851
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.3%
# Minibatch loss at step 19450: 0.135356
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.0%
# Minibatch loss at step 19500: 0.718395
# Minibatch accuracy: 68.8%
# Validation accuracy: 79.0%
# Minibatch loss at step 19550: 0.342121
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.3%
# Minibatch loss at step 19600: 0.685447
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.0%
# Minibatch loss at step 19650: 0.389986
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.8%
# Minibatch loss at step 19700: 0.594878
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.5%
# Minibatch loss at step 19750: 0.233897
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.1%
# Minibatch loss at step 19800: 0.313840
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.6%
# Minibatch loss at step 19850: 0.339102
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.2%
# Minibatch loss at step 19900: 0.008150
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.3%
# Minibatch loss at step 19950: 0.125304
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.2%
# Minibatch loss at step 20000: 0.190997
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.5%
# Minibatch loss at step 20050: 0.591965
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.6%
# Minibatch loss at step 20100: 0.451448
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.3%
# Minibatch loss at step 20150: 0.165681
# Minibatch accuracy: 100.0%
# Validation accuracy: 78.6%
# Minibatch loss at step 20200: 0.158790
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.1%
# Minibatch loss at step 20250: 0.455462
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.2%
# Minibatch loss at step 20300: 0.612735
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.4%
# Minibatch loss at step 20350: 0.361480
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.8%
# Minibatch loss at step 20400: 0.039738
# Minibatch accuracy: 100.0%
# Validation accuracy: 78.7%
# Minibatch loss at step 20450: 0.558146
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.0%
# Minibatch loss at step 20500: 0.545347
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.3%
# Minibatch loss at step 20550: 0.025091
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.5%
# Minibatch loss at step 20600: 0.078031
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.3%
# Minibatch loss at step 20650: 0.219214
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.5%
# Minibatch loss at step 20700: 0.222710
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.2%
# Minibatch loss at step 20750: 0.149012
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.4%
# Minibatch loss at step 20800: 0.319359
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.3%
# Minibatch loss at step 20850: 0.096365
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.4%
# Minibatch loss at step 20900: 0.020146
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.4%
# Minibatch loss at step 20950: 0.175600
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.5%
# Minibatch loss at step 21000: 0.409762
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.8%
# Minibatch loss at step 21050: 0.165953
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.5%
# Minibatch loss at step 21100: 0.229924
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.5%
# Minibatch loss at step 21150: 0.149250
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.4%
# Minibatch loss at step 21200: 0.029988
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.3%
# Minibatch loss at step 21250: 0.173379
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.7%
# Minibatch loss at step 21300: 0.190682
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.4%
# Minibatch loss at step 21350: 0.397015
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.3%
# Minibatch loss at step 21400: 0.674601
# Minibatch accuracy: 68.8%
# Validation accuracy: 80.0%
# Minibatch loss at step 21450: 0.421325
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.4%
# Minibatch loss at step 21500: 0.075535
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.0%
# Minibatch loss at step 21550: 0.284338
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.5%
# Minibatch loss at step 21600: 0.165754
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.8%
# Minibatch loss at step 21650: 0.599986
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.1%
# Minibatch loss at step 21700: 0.232583
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.5%
# Minibatch loss at step 21750: 0.321762
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.7%
# Minibatch loss at step 21800: 0.098618
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.7%
# Minibatch loss at step 21850: 0.361644
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.2%
# Minibatch loss at step 21900: 0.058020
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.3%
# Minibatch loss at step 21950: 0.313936
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.3%
# Minibatch loss at step 22000: 0.098699
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.4%
# Minibatch loss at step 22050: 0.415790
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.7%
# Minibatch loss at step 22100: 0.536036
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.4%
# Minibatch loss at step 22150: 0.343575
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.7%
# Minibatch loss at step 22200: 0.124955
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.2%
# Minibatch loss at step 22250: 0.941444
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.2%
# Minibatch loss at step 22300: 0.288031
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.4%
# Minibatch loss at step 22350: 0.260041
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.5%
# Minibatch loss at step 22400: 0.012539
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.1%
# Minibatch loss at step 22450: 0.322103
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.2%
# Minibatch loss at step 22500: 0.458539
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.8%
# Minibatch loss at step 22550: 0.358796
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.2%
# Minibatch loss at step 22600: 0.118956
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.4%
# Minibatch loss at step 22650: 0.337895
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.3%
# Minibatch loss at step 22700: 0.191175
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.3%
# Minibatch loss at step 22750: 0.168679
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.7%
# Minibatch loss at step 22800: 0.167030
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.8%
# Minibatch loss at step 22850: 0.276461
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.7%
# Minibatch loss at step 22900: 0.653934
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.0%
# Minibatch loss at step 22950: 0.287559
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.7%
# Minibatch loss at step 23000: 0.370531
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.6%
# Minibatch loss at step 23050: 0.256877
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.8%
# Minibatch loss at step 23100: 0.218910
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.7%
# Minibatch loss at step 23150: 0.778559
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.3%
# Minibatch loss at step 23200: 0.220513
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.6%
# Minibatch loss at step 23250: 0.847303
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.5%
# Minibatch loss at step 23300: 0.141761
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.5%
# Minibatch loss at step 23350: 0.365876
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.5%
# Minibatch loss at step 23400: 0.640740
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.8%
# Minibatch loss at step 23450: 0.095846
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.4%
# Minibatch loss at step 23500: 0.003626
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.3%
# Minibatch loss at step 23550: 0.296933
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.6%
# Minibatch loss at step 23600: 0.228819
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.6%
# Minibatch loss at step 23650: 0.352003
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.6%
# Minibatch loss at step 23700: 0.226777
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.3%
# Minibatch loss at step 23750: 0.249550
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.8%
# Minibatch loss at step 23800: 0.082275
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.7%
# Minibatch loss at step 23850: 0.739201
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.5%
# Minibatch loss at step 23900: 0.076330
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.1%
# Minibatch loss at step 23950: 0.272288
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.8%
# Minibatch loss at step 24000: 0.132384
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.0%
# Minibatch loss at step 24050: 0.045726
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.0%
# Minibatch loss at step 24100: 0.720399
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.6%
# Minibatch loss at step 24150: 0.264807
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.0%
# Minibatch loss at step 24200: 0.596054
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.0%
# Minibatch loss at step 24250: 0.484510
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.2%
# Minibatch loss at step 24300: 0.723707
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.6%
# Minibatch loss at step 24350: 0.097603
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.2%
# Minibatch loss at step 24400: 0.081561
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.9%
# Minibatch loss at step 24450: 0.085897
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.7%
# Minibatch loss at step 24500: 0.146550
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.6%
# Minibatch loss at step 24550: 0.001799
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.5%
# Minibatch loss at step 24600: 0.334619
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.5%
# Minibatch loss at step 24650: 0.662434
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.6%
# Minibatch loss at step 24700: 0.094765
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.0%
# Minibatch loss at step 24750: 0.371460
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.6%
# Minibatch loss at step 24800: 0.383009
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.4%
# Minibatch loss at step 24850: 0.159882
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.3%
# Minibatch loss at step 24900: 0.094925
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.3%
# Minibatch loss at step 24950: 0.583106
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.0%
# Minibatch loss at step 25000: 0.226611
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.0%
# Minibatch loss at step 25050: 0.362897
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.6%
# Minibatch loss at step 25100: 0.173996
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.7%
# Minibatch loss at step 25150: 0.314013
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.9%
# Minibatch loss at step 25200: 0.193289
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.0%
# Minibatch loss at step 25250: 0.172815
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.0%
# Minibatch loss at step 25300: 0.109755
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.1%
# Minibatch loss at step 25350: 0.388878
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.9%
# Minibatch loss at step 25400: 0.299932
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.6%
# Minibatch loss at step 25450: 0.295919
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.7%
# Minibatch loss at step 25500: 0.037582
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.0%
# Minibatch loss at step 25550: 0.588671
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.8%
# Minibatch loss at step 25600: 0.284444
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.9%
# Minibatch loss at step 25650: 0.372854
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.7%
# Minibatch loss at step 25700: 0.166191
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.3%
# Minibatch loss at step 25750: 0.019747
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.1%
# Minibatch loss at step 25800: 0.061095
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.4%
# Minibatch loss at step 25850: 0.110740
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.8%
# Minibatch loss at step 25900: 0.414734
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.8%
# Minibatch loss at step 25950: 0.201865
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.8%
# Minibatch loss at step 26000: 0.018850
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.1%
# Minibatch loss at step 26050: 0.242774
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.1%
# Minibatch loss at step 26100: 0.408199
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.0%
# ...
# Minibatch loss at step 41400: 0.302740
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.0%
# Minibatch loss at step 41450: 0.307236
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.8%
# Minibatch loss at step 41500: 0.239006
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.1%
# Minibatch loss at step 41550: 0.293550
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.0%
# Minibatch loss at step 41600: 0.476280
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.7%
# Minibatch loss at step 41650: 0.392164
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.6%
# Minibatch loss at step 41700: 0.319668
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.5%
# Minibatch loss at step 41750: 0.323622
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.8%
# Minibatch loss at step 41800: 0.931138
# Minibatch accuracy: 68.8%
# Validation accuracy: 79.8%
# Minibatch loss at step 41850: 0.659469
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.1%
# Minibatch loss at step 41900: 0.182781
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.6%
# Minibatch loss at step 41950: 0.390759
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.5%
# Minibatch loss at step 42000: 0.323471
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.3%
# Minibatch loss at step 42050: 0.346320
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.0%
# Minibatch loss at step 42100: 0.335010
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.1%
# Minibatch loss at step 42150: 0.441288
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.1%
# Minibatch loss at step 42200: 0.438976
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.1%
# Minibatch loss at step 42250: 0.261684
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.1%
# Minibatch loss at step 42300: 0.182678
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.3%
# Minibatch loss at step 42350: 0.224541
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.0%
# Minibatch loss at step 42400: 0.456361
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.9%
# Minibatch loss at step 42450: 0.102859
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.1%
# Minibatch loss at step 42500: 0.416055
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.0%
# Minibatch loss at step 42550: 0.332787
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.8%
# Minibatch loss at step 42600: 0.223572
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.5%
# Minibatch loss at step 42650: 0.322954
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.8%
# Minibatch loss at step 42700: 0.305838
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.7%
# Minibatch loss at step 42750: 0.225840
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.8%
# Minibatch loss at step 42800: 0.178170
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.6%
# Minibatch loss at step 42850: 0.316575
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.8%
# Minibatch loss at step 42900: 0.014883
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.1%
# Minibatch loss at step 42950: 0.112441
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.0%
# Minibatch loss at step 43000: 0.270729
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.9%
# Minibatch loss at step 43050: 0.058959
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.0%
# Minibatch loss at step 43100: 0.213039
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.1%
# Minibatch loss at step 43150: 0.274228
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.2%
# Minibatch loss at step 43200: 0.325599
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.2%
# Minibatch loss at step 43250: 0.014960
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.7%
# Minibatch loss at step 43300: 0.033204
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.7%
# Minibatch loss at step 43350: 0.056001
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.6%
# Minibatch loss at step 43400: 0.197062
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.7%
# Minibatch loss at step 43450: 0.137492
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.9%
# Minibatch loss at step 43500: 0.064450
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.9%
# Minibatch loss at step 43550: 0.016129
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.7%
# Minibatch loss at step 43600: 0.311641
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.9%
# Minibatch loss at step 43650: 0.012826
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.5%
# Minibatch loss at step 43700: 0.510833
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.6%
# Minibatch loss at step 43750: 0.162759
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.7%
# Minibatch loss at step 43800: 0.137171
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.3%
# Minibatch loss at step 43850: 0.677081
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.8%
# Minibatch loss at step 43900: 0.428065
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.0%
# Minibatch loss at step 43950: 0.322986
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.2%
# Minibatch loss at step 44000: 0.358336
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.9%
# Minibatch loss at step 44050: 0.485331
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.8%
# Minibatch loss at step 44100: 0.359441
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.9%
# Minibatch loss at step 44150: 0.277446
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.8%
# Minibatch loss at step 44200: 0.231700
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.5%
# Minibatch loss at step 44250: 0.177873
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.9%
# Minibatch loss at step 44300: 0.076748
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.2%
# Minibatch loss at step 44350: 0.455744
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.2%
# Minibatch loss at step 44400: 0.312203
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.0%
# Minibatch loss at step 44450: 0.170070
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.2%
# Minibatch loss at step 44500: 0.196082
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.0%
# Minibatch loss at step 44550: 0.166276
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.7%
# Minibatch loss at step 44600: 0.241974
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.2%
# Minibatch loss at step 44650: 0.223246
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.5%
# Minibatch loss at step 44700: 0.133877
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.3%
# Minibatch loss at step 44750: 0.086004
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.8%
# Minibatch loss at step 44800: 0.623326
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.1%
# Minibatch loss at step 44850: 0.307998
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.1%
# Minibatch loss at step 44900: 0.212608
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.0%
# Minibatch loss at step 44950: 0.087887
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.9%
# Minibatch loss at step 45000: 0.369099
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.1%
# Minibatch loss at step 45050: 0.077645
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.1%
# Minibatch loss at step 45100: 0.157104
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.0%
# Minibatch loss at step 45150: 0.625819
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.8%
# Minibatch loss at step 45200: 0.916087
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.0%
# Minibatch loss at step 45250: 0.885394
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.2%
# Minibatch loss at step 45300: 0.899321
# Minibatch accuracy: 68.8%
# Validation accuracy: 80.0%
# Minibatch loss at step 45350: 0.250535
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.0%
# Minibatch loss at step 45400: 0.108888
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.1%
# Minibatch loss at step 45450: 0.163491
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.0%
# Minibatch loss at step 45500: 0.010929
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.2%
# Minibatch loss at step 45550: 0.153680
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.7%
# Minibatch loss at step 45600: 0.067852
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.3%
# Minibatch loss at step 45650: 0.023797
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.2%
# Minibatch loss at step 45700: 0.189678
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.2%
# Minibatch loss at step 45750: 0.169925
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.3%
# Minibatch loss at step 45800: 0.610378
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.1%
# Minibatch loss at step 45850: 0.306530
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.2%
# Minibatch loss at step 45900: 0.162906
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.2%
# Minibatch loss at step 45950: 0.398720
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.3%
# Minibatch loss at step 46000: 0.016151
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.3%
# Minibatch loss at step 46050: 0.289856
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.8%
# Minibatch loss at step 46100: 0.397894
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.8%
# Minibatch loss at step 46150: 0.108344
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.7%
# Minibatch loss at step 46200: 0.420377
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.0%
# Minibatch loss at step 46250: 0.199863
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.7%
# Minibatch loss at step 46300: 0.248035
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.0%
# Minibatch loss at step 46350: 0.497284
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.3%
# Minibatch loss at step 46400: 0.133656
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.0%
# Minibatch loss at step 46450: 0.013741
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.3%
# Minibatch loss at step 46500: 0.175014
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.1%
# Minibatch loss at step 46550: 0.584540
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.2%
# Minibatch loss at step 46600: 0.025786
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.6%
# Minibatch loss at step 46650: 0.477176
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.3%
# Minibatch loss at step 46700: 0.305823
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.3%
# Minibatch loss at step 46750: 0.064798
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.6%
# Minibatch loss at step 46800: 0.005202
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.1%
# Minibatch loss at step 46850: 0.312234
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.1%
# Minibatch loss at step 46900: 0.306493
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.0%
# Minibatch loss at step 46950: 0.268731
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.8%
# Minibatch loss at step 47000: 0.087069
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.1%
# Minibatch loss at step 47050: 0.108780
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.8%
# Minibatch loss at step 47100: 0.208016
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.5%
# Minibatch loss at step 47150: 0.048462
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.2%
# Minibatch loss at step 47200: 0.063060
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.0%
# Minibatch loss at step 47250: 0.459230
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.0%
# Minibatch loss at step 47300: 0.144205
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.2%
# Minibatch loss at step 47350: 0.000653
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.9%
# Minibatch loss at step 47400: 0.006624
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.0%
# Minibatch loss at step 47450: 0.067607
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.0%
# Minibatch loss at step 47500: 0.274084
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.1%
# Minibatch loss at step 47550: 0.302098
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.2%
# Minibatch loss at step 47600: 0.562000
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.1%
# Minibatch loss at step 47650: 0.080837
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.1%
# Minibatch loss at step 47700: 0.338643
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.2%
# Minibatch loss at step 47750: 0.015874
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.0%
# Minibatch loss at step 47800: 0.353087
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.3%
# Minibatch loss at step 47850: 0.308662
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.0%
# Minibatch loss at step 47900: 0.022547
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.9%
# Minibatch loss at step 47950: 0.290664
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.3%
# Minibatch loss at step 48000: 0.216440
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.3%
# Minibatch loss at step 48050: 0.188022
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.7%
# Minibatch loss at step 48100: 0.047569
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.6%
# Minibatch loss at step 48150: 0.156681
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.1%
# Minibatch loss at step 48200: 0.378370
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.2%
# Minibatch loss at step 48250: 0.323140
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.3%
# Minibatch loss at step 48300: 0.148254
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.2%
# Minibatch loss at step 48350: 0.115874
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.3%
# Minibatch loss at step 48400: 0.768300
# Minibatch accuracy: 68.8%
# Validation accuracy: 80.2%
# Minibatch loss at step 48450: 0.189360
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.1%
# Minibatch loss at step 48500: 0.493372
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.0%
# Minibatch loss at step 48550: 0.161010
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.0%
# Minibatch loss at step 48600: 0.130806
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.8%
# Minibatch loss at step 48650: 0.332218
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.9%
# Minibatch loss at step 48700: 0.223307
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.0%
# Minibatch loss at step 48750: 0.554597
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.2%
# Minibatch loss at step 48800: 0.188823
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.2%
# Minibatch loss at step 48850: 0.143516
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.3%
# Minibatch loss at step 48900: 0.350109
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.4%
# Minibatch loss at step 48950: 0.546856
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.4%
# Minibatch loss at step 49000: 0.206851
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.6%
# Minibatch loss at step 49050: 0.681566
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.5%
# Minibatch loss at step 49100: 0.066235
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.3%
# Minibatch loss at step 49150: 0.317086
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.1%
# Minibatch loss at step 49200: 0.199126
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.7%
# Minibatch loss at step 49250: 0.083931
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.4%
# Minibatch loss at step 49300: 0.586436
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.3%
# Minibatch loss at step 49350: 0.327597
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.6%
# Minibatch loss at step 49400: 0.407850
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.1%
# Minibatch loss at step 49450: 0.003800
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.4%
# Minibatch loss at step 49500: 0.107818
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.3%
# Minibatch loss at step 49550: 0.632838
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.2%
# Minibatch loss at step 49600: 0.082899
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.4%
# Minibatch loss at step 49650: 0.118717
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.1%
# Minibatch loss at step 49700: 0.225240
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.3%
# Minibatch loss at step 49750: 0.091113
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.2%
# Minibatch loss at step 49800: 0.370263
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.0%
# Minibatch loss at step 49850: 0.627380
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.9%
# Minibatch loss at step 49900: 0.141083
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.3%
# Minibatch loss at step 49950: 0.189728
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.4%
# Minibatch loss at step 50000: 0.061335
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.0%
# Test accuracy: 95.8%
